# %% [markdown]
# > <p><small><small>This Notebook is made available subject to the licence and terms set out in the <a href = "http://www.github.com/google-deepmind/ai-foundations">AI Research Foundations Github README file</a>.

# %% [markdown]
# <img src="https://storage.googleapis.com/dm-educational/assets/ai_foundations/GDM-Labs-banner-image-C1-white-bg.png">

# %% [markdown]
# # Lab: Train Your Own Small Language Model
#
# <a href='https://colab.research.google.com/github/google-deepmind/ai-foundations/blob/master/course_1/gdm_lab_1_5_train_your_own_small_language_model.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>
#
# 40 minutes
#
# Train a transformer language model on the Africa Galore dataset.

# %% [markdown]
# ## Overview
#
# In this lab, you will make use of the data pre-processing steps that you have implememented in the previous lab and prepare the data to be used for training a transformer model. You will then train your own small language model on the Africa Galore dataset and explore its predictions. The model you will be training is referred to as a small language model because it has comparably fewer parameters (around 3.5 million instead of the approximately 1 billion of Gemma-1B) and will be trained on the small Africa Galore dataset.

# %% [markdown]
# ### What you will learn:
#
# By the end of this lab, you will know:
#
# * How to prepare a text dataset to be used for training a transformer model with Keras.
# * How to train and evaluate a small language model (SLM).

# %% [markdown]
# ### Tasks
#
# You will use an implementation of the transformer model written using [Keras](https://keras.io/). Keras is an open source deep learning framework that allows you to define neural network architectures and train models using these architectures. You will learn more about how to define models yourself in later courses. For now, you will use existing code to define the model and perform its training.
#
#
# **In this lab, you will**:
# * Load the dataset, tokenize it, and convert it to token IDs.
# * Pad the dataset such that all sequences have the same length.
# * Shuffle the examples in the dataset and group them into batches.
# * Transform the data into model inputs and model targets.
# * Train the transformer model.
#
# Note that this is quite a long lab since there are many steps that you have to go through for training a transformer language model and the training itself takes some time. If you are able to, we *highly recommend* running the code in this lab on a Colab instance with a GPU. See the section "How to use Google Colaboratory (Colab)" below for instructions on how to do this.

# %% [markdown]
# ## How to use Google Colaboratory (Colab)

# %% [markdown]
# Google Colaboratory (also known as Google Colab) is a platform that allows you to run Python code in your browser. The code is written in **cells** that are excuted on a remote server.
#
# To run a cell, hover over a cell, and click on the `run` button to its left. The run button is the circle with the triangle (▶). Alternatively, you can also click on a cell and use the keyboard combination Ctrl+Return (or ⌘+Return if you are using a Mac).
#
# To try this out, run the following cell. This should print today's day of the week below it.

# %%
from datetime import datetime
print(f"Today is {datetime.today():%A}.")

# %% [markdown]
# Note that the *order in which you run the cells matters*. When you are working through a lab, make sure to always run *all* cells in order. Otherwise, the code might not work. If you take a break while working on a lab, Colab may disconnect you and in that case, you have to execute all cells again before  continuing your work. To make this easier, you can select the cell you are currently working on and then choose __Runtime → Run before__  from the menu above (or use the keyboard combination Ctrl/⌘ + F8). This will re-execute all cells before the current one.

# %% [markdown]
# ### Using Colab with a GPU
#
# A **GPU** is a special type of hardware that can significantly speed up some types of computations of machine learning models. Several of the activities in this lab will also run a lot faster if you run them on a GPU.
#
# Follow these steps to run the activities in this lab on a GPU:
#
# 1.  In the top menu bar, click on **Runtime**.
# 2.  Select **Change runtime type** from the dropdown menu.
# 3.  In the pop-up window under **Hardware Accelerator**, select **GPU** (usually listed as `T4 GPU`).
# 5.  Click **Save**.
#
# Your Colab session will now restart with GPU access.
#
# Note that access to GPUs is limited and at times, you may not be able to run this lab on a GPU. All activities will still work but they will run slower and you will have to wait longer for some of the cells to finish running.

# %% [markdown]
# ## Imports

# %% [markdown]
# In this lab, you will make use of the Keras package for defining and training the transformer model, the [Pandas](http://pandas.pydata.org) package for reading the dataset, and the [TensorFlow](https://tensorflow.org) package for shuffling the data and grouping it into batches. Run the following cell to import these packages.

# %%
# !pip install "git+https://github.com/google-deepmind/ai-foundations.git@main"

# Monkey-patch the missing class before any gemma imports

from kauldron import kd
import dataclasses

if not hasattr(kd.ckpts, 'AbstractPartialLoader'):
    @dataclasses.dataclass(frozen=True)
    class AbstractPartialLoader:
        pass
    kd.ckpts.AbstractPartialLoader = AbstractPartialLoader

import os
os.environ["KERAS_BACKEND"] = "jax"
import re

import keras
import pandas as pd
import tensorflow as tf

from IPython.display import display, HTML
from ai_foundations import training
from ai_foundations import generation
from ai_foundations import visualizations
from ai_foundations.feedback.course_1 import slm

keras.utils.set_random_seed(812)

# %% [markdown]
# ## Loading and tokenizing the dataset
#
# Load the dataset. As in previous labs, you will use the [Africa Galore](https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore.json) dataset to train the model.

# %%
africa_galore = pd.read_json(
    "https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore.json"
)
dataset = africa_galore["description"].values
print("Loaded dataset with", dataset.shape[0], "paragraphs.")
# Out:
# Loaded dataset with 232 paragraphs.

# %% [markdown]
# ### Tokenization
#
# The following cell contains the  `SimpleWordTokenizer` class that you have encountered in the previous lab. You will use this class again to tokenize the dataset, prepare the vocabulary, and provide methods for translating tokens into token IDs and vice versa. Note that this version also adds special `<PAD>` and `<UNK>` tokens to the vocabulary. You will learn more about the purpose of these special tokens as part of this lab.
#
# Run the following cell to define the `SimpleWordTokenizer` and tokenize the Africa Galore dataset, and translate its tokens to IDs.

# %%
class SimpleWordTokenizer:
    """A simple word tokenizer.

    The tokenizer splits the text sequence based on whitespace, using the
    `encode` method to convert the text into a sequence of indices and the
    `decode` method to convert indices back into text.

    The simple word tokenizer that can be initialized with a corpus or using a
    provided vocabulary list

    Typical usage example:

        corpus = "Hello there!"
        tokenizer = SimpleWordTokenizer(text)
        print(tokenizer.encode('Hello'))

    """

    # Define constants.
    UNKNOWN_TOKEN = "<UNK>"
    PAD_TOKEN = "<PAD>"

    def __init__(self, corpus: list[str], vocabulary: list[str] | None = None):
        """Initializes the tokenizer with texts in corpus or with a vocabulary.

        Args:
          corpus: Input text dataset.
          vocabulary: A pre-defined vocabulary. If None,
              the vocabulary is automatically inferred from the texts.
        """

        if vocabulary is None:
            # Build the vocabulary from scratch.
            if isinstance(corpus, str):
                corpus = [corpus]

            # Convert text sequence to tokens.
            tokens = []
            for text in corpus:
                for token in self.space_tokenize(text):
                    tokens.append(token)

            # Create a vocabulary comprising of unique tokens.
            vocabulary = self.build_vocabulary(tokens)

            # Add special unknown and pad tokens to the vocabulary list.
            self.vocabulary = (
                [self.PAD_TOKEN] + vocabulary + [self.UNKNOWN_TOKEN]
            )

        else:
            self.vocabulary = vocabulary

        # Size of vocabulary.
        self.vocabulary_size = len(self.vocabulary)

        # Create token-to-index and index-to-token mappings.
        self.token_to_index = {}
        self.index_to_token = {}
        # Loop through all tokens in the vocabulary. enumerate automatically
        # assigns a unique index to each token.
        for index, token in enumerate(self.vocabulary):
            self.token_to_index[token] = index
            self.index_to_token[index] = token

        # Map the special tokens to their IDs.
        self.pad_token_id = self.token_to_index[self.PAD_TOKEN]
        self.unknown_token_id = self.token_to_index[self.UNKNOWN_TOKEN]

    def space_tokenize(self, text: str) -> list[str]:
        """Splits a given text on whitespace into tokens.

        Args:
            text: Text to split on whitespace.

        Returns:
            List of tokens after splitting `text`.
        """

        # Use re.split such that multiple spaces are treated as a single
        # separator.
        return re.split(" +", text)

    def join_text(self, text_list: list[str]) -> str:
        """Combines a list of tokens into a single string.

        The combined tokens, as a single string, are separated by spaces in the
        string.

        Args:
            text_list: List of tokens to be joined.

        Returns:
            String with all tokens joined with a whitespace.

        """
        return " ".join(text_list)

    def build_vocabulary(self, tokens: list[str]) -> list[str]:
        """Create a vocabulary list from the list of tokens.

        Args:
            tokens: The list of tokens in the dataset.

        Returns:
            List of unique tokens (vocabulary) in the dataset.
        """
        return sorted(list(set(tokens)))

    def encode(self, text: str) -> list[int]:
        """Encodes a text sequence into a list of indices.

        Args:
            text: The input text to be encoded.

        Returns:
            A list of indices corresponding to the tokens in the input text.
        """

        # Convert tokens into indices.
        indices = []
        unk_index = self.token_to_index[self.UNKNOWN_TOKEN]
        for token in self.space_tokenize(text):
            token_index = self.token_to_index.get(token, unk_index)
            indices.append(token_index)

        return indices

    def decode(self, indices: int | list[int]) -> str:
        """Decodes a list (or single index) of integers back into tokens.

        Args:
            indices: A single index or a list of indices to be
                decoded into tokens.

        Returns:
            A string of decoded tokens corresponding to the input indices.
        """

        # If a single integer is passed, convert it into a list.
        if isinstance(indices, int):
            indices = [indices]

        # Map indices to tokens.
        tokens = []
        for index in indices:
            token = self.index_to_token.get(index, self.unknown_token_id)
            tokens.append(token)

        # Join the decoded tokens into a single string.
        return self.join_text(tokens)


# Initialize the tokenizer. This will build the tokenizer's vocabulary with
# all the tokens that appear in the dataset.
tokenizer = SimpleWordTokenizer(dataset)

# Translate all tokens to their corresponding IDs.
encoded_tokens = []
for text in dataset:
    # Split text into tokens and translate the tokens to token IDs.
    token_ids = tokenizer.encode(text)
    encoded_tokens.append(token_ids)

# %% [markdown]
# To verify that this process was successful, inspect the first ten token IDs in the first example.

# %%
encoded_tokens[0][:10]
# Out:
# [814, 511, 985, 5092, 4802, 5183, 2800, 1363, 4792, 2134]

# %% [markdown]
# ## Padding the dataset

# %% [markdown]
# ------
# > **ℹ️ Info: Padding and truncating**
# >
# >The input to transformer models (or deep learning models more generally) is a **matrix** where each row corresponds to the data for one example in the dataset. In the case of the language model you will be training, each paragraph from the Africa Galore dataset constitutes an example. The input should therefore be a matrix that has the IDs of every token in a paragraph. In this matrix, the first entry of a row should be the ID of the first token, the second entry should be the ID of the second token, the third entry should be the ID of the third token, and so on.
# >
# >However, the paragraphs in a dataset rarely all have exactly the same length. This causes a problem when you try to combine the data of multiple paragraphs into a matrix, since every row in a matrix must have the same number of entries.
# >
# >There are two common solutions to this problem:
# >1. You can use a special `<PAD>` token to ensure that all sequences have the same length. This way, you can pad shorter paragraphs to match the length of the longest paragraph. This is done by adding `<PAD>` tokens at the beginning or the end of the paragraph. This results in all paragraphs having exactly the same length so that they can be combined in one matrix.
# >2. Another option is to truncate paragraphs. That is, removing the tokens at the beginning or the end of a paragraph so that they have the length of the shortest paragraph. This, however, may remove a lot of information from the dataset. For example, if the shortest paragraph has only five tokens, then you would shorten every paragraph to five tokens and remove almost all tokens.
# >
# > It is also possible to combine both of these methods so that you choose a target length. That way, very long paragraphs that exceed this length are truncated and short paragraphs whose length is below the target length are padded.
# >
# >The combination of truncating and padding is what is usually done in practice. You will implement this in the next activity to prepare the data for training the model.
# ------

# %% [markdown]
# ### Coding Activity 1: Compute length statistics
#
# To get a sense of what the dataset looks like and how much padding is needed, compute some statstics of the length of the dataset.
#
# First, look at the length of the first paragraph:

# %%
print(f"Length of first paragraph: {len(encoded_tokens[0]):,}")
# Out:
# Length of first paragraph: 118

# %% [markdown]
# ------
# > 💻 **Your task:**
# >
# > Complete the following cell to compute the length of the shortest paragraph and the length of the longest paragraph.
# >
# > There are multiple ways you go about this. For example, you could write a loop that goes through all paragraphs in `encoded_tokens`. You could update variables for the shortest and longest paragraph length whenever you encounter a shorter or longer paragraph than previously seen.
# >
# > Alternatively, you can use the `min` and `max` functions in combination with the `len` function in Python. For example, if you have a list of lists `list_of_lists`, then
# >`min(list_of_lists, key=len)` returns the list in `list_of_lists` with the shortest list (or one of them if there are multiple that have the same length).
# ------

# %%
# Add your code to compute the length of the shortest paragraph here.
shortest_paragraph_length = min(len (p) for p in encoded_tokens)

# Add your code to compute the length of the longest paragraph here.
longest_paragraph_length = max(len (p) for p in encoded_tokens)

print(f"Length of the shortest paragraph is:", shortest_paragraph_length)
print(f"Length of the longest paragraph is:", longest_paragraph_length)
# Out:
# Length of the shortest paragraph is: 26
# Length of the longest paragraph is: 318

# %%
# @title Run this cell to test your code

slm.test_max_min_seqlen(
    shortest_paragraph_length, longest_paragraph_length, encoded_tokens
)
# Out:
# ✅ Nice! Your answer looks correct.

# %% [markdown]
# You can now use this information to set the target length (`max_length`) for padding and truncating the paragraphs in your dataset. The cell below does this behind the scenes using the [`keras.preprocessing.sequence.pad_sequences`](https://github.com/keras-team/keras/blob/v3.10.0/keras/src/utils/sequence_utils.py#L12) function from the Keras package.
#
# Change the value below to different values, and observe how the list of token IDs for the first paragraph changes. What happens when you set `max_length` to a very small value? What happens when you set it to the length of the longest paragraph?

# %%
# @title Set `max_length` for padding and truncating data.

max_length = 10  # @param {type: "number"}

if max_length <= 0:
    display(
        HTML(
            f"<h3>Error:</h3><p>Max length must be greater than 0. Please"
            f" increase <code>max_length</code>.</p><p></p>"
        )
    )

elif max_length > longest_paragraph_length:
    display(
        HTML(
            f"<h3>Error:</h3><p>The padding token <code>"
            f" {tokenizer.pad_token_id}</code> will be added to all"
            f" sequences - you probably don't want that. Please reduce"
            f" <code>max_length</code>.</p><p></p>"
        )
    )

else:
    if max_length < longest_paragraph_length:
        display(
            HTML(
                f"<p><strong>Note:</strong> The longest paragraph has"
                f" {longest_paragraph_length} tokens,"
                f" but <code>max_length</code> is set to {max_length}."
                f" Paragraphs longer than <code>max_length</code> will be"
                " truncated.</p><p></p>"
            )
        )

    padded_sequences = keras.preprocessing.sequence.pad_sequences(
        encoded_tokens,
        maxlen=max_length,
        padding="post",
        truncating="post",
        value=tokenizer.pad_token_id,
    )

    print("New length of first paragraph:", len(padded_sequences[0]), "\n")

    print(
        "Padding makes the length of all sequences the same as the specified"
        " `max_length`."
    )

    print(
        "Notice the padded token IDs {tokenizer.pad_token_id} appearing at the"
        f" end of the sequence.\n"
    )
    print("Padded tokens of first paragraph:\n", padded_sequences[0])
# Out:
# <p><strong>Note:</strong> The longest paragraph has 318 tokens, but <code>max_length</code> is set to 10. Paragraphs longer than <code>max_length</code> will be truncated.</p><p></p>
# New length of first paragraph: 10
#
# Padding makes the length of all sequences the same as the specified `max_length`.
# Notice the padded token IDs {tokenizer.pad_token_id} appearing at the end of the sequence.
#
# Padded tokens of first paragraph:
#  [ 814  511  985 5092 4802 5183 2800 1363 4792 2134]

# %% [markdown]
# ## Prepare input and target
#
# Recall that the task of a language model is to predict the next token given a context of previous tokens. In the case of n-gram models, you could "teach" the model to do this by counting n-grams in the corpus and directly computing the probabilities from the n-gram counts.
#
# Transformers have a more involved training procedure. They repeatedly make guesses of what the next token should be. If they get this guess wrong, the training procedure updates the model parameters. That way, the model is more likely to make a correct guess next time.
#
# For this training procedure, you have to prepare the data such that you have a separate *input* and *target* dataset:
#
# * **Input**: The input is a sequence of tokens that is passed into the transformer model. This may be a part of a paragraph, a full paragraph, or even multiple paragraphs, depending on how the data is structured. The input will contain everything but the last token since there is no next token for the last token.
#
# * **Target**: The target sequence is what you want the model to predict from the input. The target will be the same as the input sequence, but *shifted left* by one token. This means the target will always contain the next token that should follow the input sequence. The target sequence will contain everything but the first word. That is because the transformer always needs at least one token as input, so it will start by predicting the next word.
#
# For example, if your dataset consists of the sentence "Table Mountain is beautiful," the corresponding input and target sequences would look as follows:
# * Input: `["Table", "Mountain", "is"]` (last token removed).
# * Target: `["Mountain", "is", "beautiful"]` (shifted by one token).
#
# As mentioned above, the input sequence and the target sequence will actually be the corresponding token IDs instead of the raw tokens. The raw tokens are included here to make the example more readable.

# %% [markdown]
# Run the following cell to prepare the input and target sequence for training the transformer model.

# %%
# Prepare input and target for the transformer model.
# For each example, extract all tokens except the last one.
input_sequences = padded_sequences[:, :-1]
# For each example, extract all tokens except the first one.
target_sequences = padded_sequences[:, 1:]

# %% [markdown]
# To check that the input sequence and the target sequence have been properly prepared, print the first ten tokens in the input and the target sequence.

# %%
print("First 10 token IDs in first input sequence:", input_sequences[0, :10])
print(
    "First 10 tokens in first input sequence:",
    tokenizer.decode(input_sequences[0, :10]),
)

print("\n")

print("First 10 token IDs in first target sequence:", target_sequences[0, :10])
print(
    "First 10 tokens in target sequence:",
    tokenizer.decode(target_sequences[0, :10])
)
# Out:
# First 10 token IDs in first input sequence: [ 814  511  985 5092 4802 5183 2800 1363 4792]
# First 10 tokens in first input sequence: The Lagos air was thick with humidity, but the
#
#
# First 10 token IDs in first target sequence: [ 511  985 5092 4802 5183 2800 1363 4792 2134]
# First 10 tokens in target sequence: Lagos air was thick with humidity, but the energy

# %% [markdown]
# You should see in the output above that the target sequence is the input sequence shifted by one token to the left.

# %% [markdown]
# When you set the maximum paragraph length `max_length` previously, you were considering all tokens, including the first and the last token of each paragraph. However, in the `input_sequences`, you removed the first token from each paragraph. In the `target_sequences`, you removed the last token. So, the maximum length of the data in `input_sequences` and `target_sequences` is now one token shorter.
#
# Run the following cell to update the `max_length` variable. This variable will be used as a parameter of the transformer model and needs to accurately reflect what the length of each (padded) paragraph in your input data is.

# %%
input_sequences = padded_sequences[:, :-1]
target_sequences = padded_sequences[:, 1:]

max_length = input_sequences.shape[1]
print(max_length)
# Out:
# 9

# %% [markdown]
# ## Shuffle the dataset and specify the batch size

# %% [markdown]
# -------
# > **ℹ️ Info: The purpose of shuffling and batches**
# >
# >The final step before you can train your small language model is to split the data into groups of a handful of paragraphs, called **batches**. Furthermore, there is often some order in your data. For example, in the Africa Galore dataset, all examples concerning food appear one after each other. When training a model, however, it is generally best to include a very diverse set of paragraphs in one batch. This can be achieved by **shuffling** the data in the dataset so that all paragraphs appear in random order before splitting them up into batches. Note that the order of tokens within a paragraph must remain intact since you would end up with word puzzles otherwise.
# >
# >For splitting the dataset into batches, you need to define the **batch size**, that is, the number of paragraphs that should be included in one batch. Increasing the batch size usually speeds up training of the model and can also lead to better models. At the same time, however, larger batch sizes require more memory. If you set the batch size too large, you may get "out of memory" errors that indicate that you do not have enough memory available to train the model. You will learn more about dealing with methods for reducing memory in later courses.
# >
# >The figure below shows a dataset with seven paragraphs. Each paragraph is padded to `max_length`. In this case, it is set to the length of the longest paragraph. The dataset is then shuffled and split into batches of size 3. Note that the final batch only contains one paragraph, since the total number of paragraphs is 7 and not divisible by 3.
# > <img src='https://storage.googleapis.com/dm-educational/assets/ai_foundations/evolve_graphic.png' width='1000'>
# ------

# %% [markdown]
# The cell below implements the shuffling of the dataset and splitting it into batches. The result of this is a list of matrices referred to as **tensors**. Each matrix corresponds to a batch and contains all the token IDs for all paragraphs in that batch.

# %%
# Create TensorFlow dataset to prepare sequences.
tf_dataset = tf.data.Dataset.from_tensor_slices((input_sequences, target_sequences))

# Randomly shuffle the dataset.
# The buffer_size determines how many examples from the dataset
# are held in memory before shuffling.
# If you are working with a very large dataset,
# reduce the buffer_size as needed.
tf_dataset = tf_dataset.shuffle(buffer_size=len(input_sequences))

# Specify batch size.
batch_size = 32  # @param {type: "number"}

# Create batches.
batches = tf_dataset.batch(batch_size)

for batch in batches.take(1):
    print(batch)
# Out:
# (<tf.Tensor: shape=(32, 9), dtype=int32, numpy=
# array([[ 814, 2406, 5117, 1691, 2671,  912, 3872, 2846, 3541],
#        [ 814, 3116,   61, 3084, 3531, 1387, 4792,   23, 3522],
#        [ 814, 4079, 1171, 3522,  170, 3406, 2332, 4792, 4380],
#        [ 262, 3315, 2932,  912, 4542, 1214, 2416, 3215, 3470],
#        [ 814,  577, 1590, 3522,  632,  158, 2146,  912,  577],
#        [ 236, 2932,  912, 3775,  876,  163, 2010, 3179, 2464],
#        [ 616, 2932,  912, 2373,  264, 4566, 3179, 5183, 1234],
#        [ 877, 4810, 4617, 4792, 3375, 3515, 1030, 2077, 4425],
#        [ 893, 5092, 4815, 4403, 4298, 5142, 3155, 2416,  394],
#        [ 251, 1063,  912, 3775,  337, 1030,  269,  163, 2617],
#        [ 272, 2932,  912, 4493,  775,  163, 5017, 4009, 3531],
#        [ 814, 4661, 1171, 1992, 5087, 3541, 4792, 2566, 4173],
#        [ 173, 5092, 2806, 4403, 2677, 5142, 3155, 2416,  912],
#        [ 440,  615,  662, 2932,  906, 3036, 1030, 3375, 2270],
#        [ 248, 2932,  912, 1778, 4694, 2010, 3179, 2464, 4792],
#        [ 521, 1063,  912, 1964, 2628, 3522, 3854, 2436, 2196],
#        [ 866, 2932,  912, 4890,  775,  163, 2453, 1987, 1307],
#        [ 479, 2932,  912,  402, 4398, 3179, 3522, 4093, 3741],
#        [ 448, 4792, 2689, 3522,  610, 4792, 1069, 3522, 4354],
#        [ 814,  141, 4365, 4305, 2856, 4792, 2171, 3105, 1093],
#        [ 366, 5092, 4815, 4403, 4298, 5142, 3155, 2416,  912],
#        [ 814,  630, 3027, 2265, 2932, 4511, 2856, 3629, 3522],
#        [ 850, 2932,  912, 1889, 3187, 3782, 4789, 2932,  912],
#        [ 486, 1467, 2932,  912, 3319, 4488, 4747, 2142, 1637],
#        [ 808, 2932,  912, 2758, 1187, 2464,  356, 3179, 2464],
#        [ 171,  912, 1362, 3369,  192, 2303, 4792, 3609, 3522],
#        [ 322, 4228, 2464,  548, 2932, 1574, 3115, 4849, 4792],
#        [ 814,  562,  576, 4792, 3534, 5076, 1540, 3522,  563],
#        [ 860, 2932,  912, 4890,  718, 1187, 3179, 2464, 2309],
#        [ 605, 2932,  912, 4890, 2309, 3315, 1214, 2464,  485],
#        [ 192, 5092, 2806, 4403, 4298, 5142, 3155, 2416,  912],
#        [ 814,  167, 3027, 2265, 2932, 3542, 3522, 4792, 3036]],
#       dtype=int32)>, <tf.Tensor: shape=(32, 9), dtype=int32, numpy=
# array([[2406, 5117, 1691, 2671,  912, 3872, 2846, 3541, 3575],
#        [3116,   61, 3084, 3531, 1387, 4792,   23, 3522, 4792],
#        [4079, 1171, 3522,  170, 3406, 2332, 4792, 4380, 1147],
#        [3315, 2932,  912, 4542, 1214, 2416, 3215, 3470, 1641],
#        [ 577, 1590, 3522,  632,  158, 2146,  912,  577, 1561],
#        [2932,  912, 3775,  876,  163, 2010, 3179, 2464, 2005],
#        [2932,  912, 2373,  264, 4566, 3179, 5183, 1234, 2610],
#        [4810, 4617, 4792, 3375, 3515, 1030, 2077, 4425, 2932],
#        [5092, 4815, 4403, 4298, 5142, 3155, 2416,  394, 1842],
#        [1063,  912, 3775,  337, 1030,  269,  163, 2617, 3265],
#        [2932,  912, 4493,  775,  163, 5017, 4009, 3531, 4276],
#        [4661, 1171, 1992, 5087, 3541, 4792, 2566, 4173, 3522],
#        [5092, 2806, 4403, 2677, 5142, 3155, 2416,  912, 3746],
#        [ 615,  662, 2932,  906, 3036, 1030, 3375, 2270, 2497],
#        [2932,  912, 1778, 4694, 2010, 3179, 2464, 4792, 2465],
#        [1063,  912, 1964, 2628, 3522, 3854, 2436, 2196, 3541],
#        [2932,  912, 4890,  775,  163, 2453, 1987, 1307,  814],
#        [2932,  912,  402, 4398, 3179, 3522, 4093, 3741, 4789],
#        [4792, 2689, 3522,  610, 4792, 1069, 3522, 4354, 3265],
#        [ 141, 4365, 4305, 2856, 4792, 2171, 3105, 1093,  191],
#        [5092, 4815, 4403, 4298, 5142, 3155, 2416,  912, 3981],
#        [ 630, 3027, 2265, 2932, 4511, 2856, 3629, 3522,  337],
#        [2932,  912, 1889, 3187, 3782, 4789, 2932,  912, 4542],
#        [1467, 2932,  912, 3319, 4488, 4747, 2142, 1637, 2856],
#        [2932,  912, 2758, 1187, 2464,  356, 3179, 2464, 2585],
#        [ 912, 1362, 3369,  192, 2303, 4792, 3609, 3522, 2804],
#        [4228, 2464,  548, 2932, 1574, 3115, 4849, 4792, 4008],
#        [ 562,  576, 4792, 3534, 5076, 1540, 3522,  563,  591],
#        [2932,  912, 4890,  718, 1187, 3179, 2464, 2309, 1133],
#        [2932,  912, 4890, 2309, 3315, 1214, 2464,  485, 3626],
#        [5092, 2806, 4403, 4298, 5142, 3155, 2416,  912, 4279],
#        [ 167, 3027, 2265, 2932, 3542, 3522, 4792, 3036, 1030]],
#       dtype=int32)>)

# %% [markdown]
# Run the following cell to count the total number of batches:

# %%
total_batches = 0
for batch in batches:
    total_batches += 1
print("Total number of batches is:", total_batches)
# Out:
# Total number of batches is: 8

# %% [markdown]
# ## Train a small language model (SLM)

# %% [markdown]
# You have now done all the preparatory work and are ready to train your small language model. As mentioned above, this model has around 3.5 million parameters. It is therefore  a lot smaller than so-called large language models that are used in production. For example, the Google Gemini model has billions of parameters and was trained on a much bigger dataset than the Africa Galore dataset.
#
# The size of the transformer model and the amount of training data has a strong impact on its performance. Larger models with more parameters have the capacity to learn more complex patterns and deliver better accuracy. However, they also require more computational resources, memory, and processing power. This can lead to longer training times i.e., how long the model needs to update to reach optimal performance, and higher costs. You would not be able to train a very large model in a Colab notebook. Therefore, you will be training a much smaller model here. Despite this, the overall process for training a large language model is the same as the process for training a small language model.
#
# ------
# > **ℹ️ Info: Parameters of a transformer model**
# >
# > **Parameters** are a set of numbers that guide the model to perform whatever task it was trained to do. In the case of transformer models, the parameters are less interpretable. They are often a very large collection of numbers that determine the model behavior.
# >
# > The parameters of a transformer model are updated after processing each batch of paragraphs. At the start of the training, the parameters are intialized with random numbers.
# >Models are then usually trained by processing the data multiple times. Going through the data once is known as an **iteration** or **epoch**. During each training iteration, the parameters are updated so that they lead to better predictions of the next token.
# ------

# %% [markdown]
# ### Initialize the model
#
# The `create_model` function used below builds a transformer model. It takes two parameters:
#
# * `max_length`: The maximum length of a paragraph in the dataset (which you set above). The model will only be able to process sequences up to this length.
# * `vocabulary_size`: The size of the vocabulary. That is the number of unique tokens in the dataset. This is used in two ways. Firstly, it is used to determine the number of unique inputs the model should expect. Secondly, it determines how many different tokens the model can predict. You can get this information from the tokenizer that you defined above by using its `vocabulary_size` property.
# * `learning_rate`: How quickly the parameters should be updated. Setting this to a higher value can speed up training but may result in a worse model. Setting this to a lower value likely improves how the model learns but may slow down training. For now, you do not have to change this value and you will learn more about this setting in later courses.

# %%
# model = training.create_model(
#     max_length=max_length,
#     vocabulary_size=tokenizer.vocabulary_size,
#     learning_rate=1e-4
# )
model = training.create_model(
    max_length=max_length,
    vocabulary_size=tokenizer.vocabulary_size,
    learning_rate=1e-5,
    num_heads=4,      # up from 2
    num_blocks=2,     # up from 1
    embedding_dim=256,
    mlp_dim=512, # up from 256
    dropout_rate=0.1
)

# %% [markdown]
# ### Initialize a callback function
#
# Training can take a while. You want to make sure that the model predictions actually get better over time. One way to do this is to define a **callback function** that is used to regularly print what the model would generate for one prompt.
#
# For example, the callback function defined in the following cell will print ten tokens for the prompt "Abeni," after every 10 training iterations.

# %%
prompt = "Abeni,"
prompt_ids = tokenizer.encode(prompt)
text_gen_callback = training.TextGenerator(
    max_tokens=10, start_tokens=prompt_ids, tokenizer=tokenizer, print_every=10
)

# %% [markdown]
# ### Run the training
#
# Run the following cell to train the model. As mentioned above, the training process updates the model parameter after processing each batch. This is known as a step in the training process.
#
# An epoch involves processing all batches in the dataset. Before training the model, you have to set the number of times the training process should process the datset. This is done by setting the number of epochs (`num_epochs`).
#
# You will likely get the best results if you train the model for at least 200 epochs. But if training is taking a long time, you can reduce the number of epochs. If the model does not perform well after 200 epochs, you can train it for additional epochs by adjusting the number below and re-running the cell. This will continue training your model.
#
# If you want to reset the training, re-run the previous cells before running the cell below.

# %%
num_epochs = 1000  # @param {type: "number"}
# verbose=2: Instructs the model.fit method to print one line per
# epoch so you see how the loss is decreasing and generated texts improving.
history = model.fit(
    x=batches, verbose=2, epochs=num_epochs, callbacks=[text_gen_callback]
)
# Out:
# Epoch 1/1000
# 8/8 - 12s - 1s/step - loss: 8.5628
# Epoch 2/1000
# 8/8 - 4s - 450ms/step - loss: 8.4971
# Epoch 3/1000
# 8/8 - 0s - 7ms/step - loss: 8.4405
# Epoch 4/1000
# 8/8 - 0s - 7ms/step - loss: 8.3870
# Epoch 5/1000
# 8/8 - 0s - 6ms/step - loss: 8.3305
# Epoch 6/1000
# 8/8 - 0s - 4ms/step - loss: 8.2793
# Epoch 7/1000
# 8/8 - 0s - 5ms/step - loss: 8.2297
# Epoch 8/1000
# 8/8 - 0s - 4ms/step - loss: 8.1782
# Epoch 9/1000
# 8/8 - 0s - 5ms/step - loss: 8.1340
# Epoch 10/1000
# Generated text:
#  Abeni, species magic warming market. Ankara smoothie resilience, glint adaptability. aroma.
#
# 8/8 - 1s - 79ms/step - loss: 8.0880
# Epoch 11/1000
# 8/8 - 0s - 4ms/step - loss: 8.0461
# Epoch 12/1000
# 8/8 - 0s - 4ms/step - loss: 7.9977
# Epoch 13/1000
# 8/8 - 0s - 4ms/step - loss: 7.9592
# Epoch 14/1000
# 8/8 - 0s - 4ms/step - loss: 7.9174
# Epoch 15/1000
# 8/8 - 0s - 4ms/step - loss: 7.8801
# Epoch 16/1000
# 8/8 - 0s - 4ms/step - loss: 7.8429
# Epoch 17/1000
# 8/8 - 0s - 4ms/step - loss: 7.8108
# Epoch 18/1000
# 8/8 - 0s - 4ms/step - loss: 7.7748
# Epoch 19/1000
# 8/8 - 0s - 4ms/step - loss: 7.7387
# Epoch 20/1000
# Generated text:
#  Abeni, rounded enjoyment Nutrients adapted Earth. garden, pace, sauces, guarded flat-topped
#
# 8/8 - 0s - 20ms/step - loss: 7.7045
# Epoch 21/1000
# 8/8 - 0s - 4ms/step - loss: 7.6720
# Epoch 22/1000
# 8/8 - 0s - 5ms/step - loss: 7.6407
# Epoch 23/1000
# 8/8 - 0s - 4ms/step - loss: 7.6085
# Epoch 24/1000
# 8/8 - 0s - 4ms/step - loss: 7.5788
# Epoch 25/1000
# 8/8 - 0s - 4ms/step - loss: 7.5496
# Epoch 26/1000
# 8/8 - 0s - 4ms/step - loss: 7.5198
# Epoch 27/1000
# 8/8 - 0s - 4ms/step - loss: 7.4893
# Epoch 28/1000
# 8/8 - 0s - 4ms/step - loss: 7.4607
# Epoch 29/1000
# 8/8 - 0s - 4ms/step - loss: 7.4332
# Epoch 30/1000
# Generated text:
#  Abeni, search textile color, peanuts, Then that's dates partially used dog.
#
# 8/8 - 0s - 15ms/step - loss: 7.4064
# Epoch 31/1000
# 8/8 - 0s - 4ms/step - loss: 7.3791
# Epoch 32/1000
# 8/8 - 0s - 4ms/step - loss: 7.3511
# Epoch 33/1000
# 8/8 - 0s - 4ms/step - loss: 7.3241
# Epoch 34/1000
# 8/8 - 0s - 4ms/step - loss: 7.3002
# Epoch 35/1000
# 8/8 - 0s - 4ms/step - loss: 7.2716
# Epoch 36/1000
# 8/8 - 0s - 4ms/step - loss: 7.2438
# Epoch 37/1000
# 8/8 - 0s - 4ms/step - loss: 7.2153
# Epoch 38/1000
# 8/8 - 0s - 4ms/step - loss: 7.1933
# Epoch 39/1000
# 8/8 - 0s - 4ms/step - loss: 7.1660
# Epoch 40/1000
# Generated text:
#  Abeni, Ghanaian of experienced salty sunshine, avocados, sausage" African eastern hot
#
# 8/8 - 0s - 17ms/step - loss: 7.1395
# Epoch 41/1000
# 8/8 - 0s - 4ms/step - loss: 7.1186
# Epoch 42/1000
# 8/8 - 0s - 4ms/step - loss: 7.0896
# Epoch 43/1000
# 8/8 - 0s - 4ms/step - loss: 7.0663
# Epoch 44/1000
# 8/8 - 0s - 4ms/step - loss: 7.0420
# Epoch 45/1000
# 8/8 - 0s - 5ms/step - loss: 7.0167
# Epoch 46/1000
# 8/8 - 0s - 4ms/step - loss: 6.9939
# Epoch 47/1000
# 8/8 - 0s - 4ms/step - loss: 6.9657
# Epoch 48/1000
# 8/8 - 0s - 4ms/step - loss: 6.9452
# Epoch 49/1000
# 8/8 - 0s - 4ms/step - loss: 6.9178
# Epoch 50/1000
# Generated text:
#  Abeni, day cocktail braai. (maize key Instantly reading southern Xhosa grains
#
# 8/8 - 0s - 15ms/step - loss: 6.8956
# Epoch 51/1000
# 8/8 - 0s - 4ms/step - loss: 6.8687
# Epoch 52/1000
# 8/8 - 0s - 4ms/step - loss: 6.8455
# Epoch 53/1000
# 8/8 - 0s - 4ms/step - loss: 6.8211
# Epoch 54/1000
# 8/8 - 0s - 4ms/step - loss: 6.8004
# Epoch 55/1000
# 8/8 - 0s - 4ms/step - loss: 6.7746
# Epoch 56/1000
# 8/8 - 0s - 4ms/step - loss: 6.7529
# Epoch 57/1000
# 8/8 - 0s - 4ms/step - loss: 6.7297
# Epoch 58/1000
# 8/8 - 0s - 4ms/step - loss: 6.7063
# Epoch 59/1000
# 8/8 - 0s - 4ms/step - loss: 6.6811
# Epoch 60/1000
# Generated text:
#  Abeni, lime African snack. legs climate, plantain. extract played look Ramadan,
#
# 8/8 - 0s - 15ms/step - loss: 6.6585
# Epoch 61/1000
# 8/8 - 0s - 4ms/step - loss: 6.6375
# Epoch 62/1000
# 8/8 - 0s - 5ms/step - loss: 6.6145
# Epoch 63/1000
# 8/8 - 0s - 4ms/step - loss: 6.5924
# Epoch 64/1000
# 8/8 - 0s - 4ms/step - loss: 6.5722
# Epoch 65/1000
# 8/8 - 0s - 5ms/step - loss: 6.5480
# Epoch 66/1000
# 8/8 - 0s - 4ms/step - loss: 6.5273
# Epoch 67/1000
# 8/8 - 0s - 4ms/step - loss: 6.5070
# Epoch 68/1000
# 8/8 - 0s - 5ms/step - loss: 6.4817
# Epoch 69/1000
# 8/8 - 0s - 5ms/step - loss: 6.4609
# Epoch 70/1000
# Generated text:
#  Abeni, based flowers Fura Park, quarter traditional simple buttermilk. enticing harmonies
#
# 8/8 - 0s - 16ms/step - loss: 6.4403
# Epoch 71/1000
# 8/8 - 0s - 4ms/step - loss: 6.4184
# Epoch 72/1000
# 8/8 - 0s - 4ms/step - loss: 6.3957
# Epoch 73/1000
# 8/8 - 0s - 5ms/step - loss: 6.3766
# Epoch 74/1000
# 8/8 - 0s - 5ms/step - loss: 6.3548
# Epoch 75/1000
# 8/8 - 0s - 4ms/step - loss: 6.3354
# Epoch 76/1000
# 8/8 - 0s - 4ms/step - loss: 6.3126
# Epoch 77/1000
# 8/8 - 0s - 4ms/step - loss: 6.2953
# Epoch 78/1000
# 8/8 - 0s - 4ms/step - loss: 6.2681
# Epoch 79/1000
# 8/8 - 0s - 4ms/step - loss: 6.2486
# Epoch 80/1000
# Generated text:
#  Abeni, is African Kofi, Wolf historic tropical family evolved Professor fried
#
# 8/8 - 0s - 15ms/step - loss: 6.2295
# Epoch 81/1000
# 8/8 - 0s - 4ms/step - loss: 6.2108
# Epoch 82/1000
# 8/8 - 0s - 4ms/step - loss: 6.1900
# Epoch 83/1000
# 8/8 - 0s - 5ms/step - loss: 6.1684
# Epoch 84/1000
# 8/8 - 0s - 5ms/step - loss: 6.1522
# Epoch 85/1000
# 8/8 - 0s - 4ms/step - loss: 6.1295
# Epoch 86/1000
# 8/8 - 0s - 4ms/step - loss: 6.1086
# Epoch 87/1000
# 8/8 - 0s - 4ms/step - loss: 6.0882
# Epoch 88/1000
# 8/8 - 0s - 4ms/step - loss: 6.0740
# Epoch 89/1000
# 8/8 - 0s - 4ms/step - loss: 6.0516
# Epoch 90/1000
# Generated text:
#  Abeni, fruity leo), National versatile rock. anything. family "grilled curiosity. boundary
#
# 8/8 - 0s - 15ms/step - loss: 6.0330
# Epoch 91/1000
# 8/8 - 0s - 4ms/step - loss: 6.0166
# Epoch 92/1000
# 8/8 - 0s - 4ms/step - loss: 5.9959
# Epoch 93/1000
# 8/8 - 0s - 5ms/step - loss: 5.9778
# Epoch 94/1000
# 8/8 - 0s - 5ms/step - loss: 5.9592
# Epoch 95/1000
# 8/8 - 0s - 5ms/step - loss: 5.9408
# Epoch 96/1000
# 8/8 - 0s - 4ms/step - loss: 5.9224
# Epoch 97/1000
# 8/8 - 0s - 4ms/step - loss: 5.9046
# Epoch 98/1000
# 8/8 - 0s - 4ms/step - loss: 5.8908
# Epoch 99/1000
# 8/8 - 0s - 4ms/step - loss: 5.8715
# Epoch 100/1000
# Generated text:
#  Abeni, Awa patterns print plantains teff nutritious coast thatched indigo fritters
#
# 8/8 - 0s - 15ms/step - loss: 5.8525
# Epoch 101/1000
# 8/8 - 0s - 4ms/step - loss: 5.8374
# Epoch 102/1000
# 8/8 - 0s - 4ms/step - loss: 5.8223
# Epoch 103/1000
# 8/8 - 0s - 4ms/step - loss: 5.8029
# Epoch 104/1000
# 8/8 - 0s - 4ms/step - loss: 5.7902
# Epoch 105/1000
# 8/8 - 0s - 4ms/step - loss: 5.7730
# Epoch 106/1000
# 8/8 - 0s - 4ms/step - loss: 5.7541
# Epoch 107/1000
# 8/8 - 0s - 5ms/step - loss: 5.7391
# Epoch 108/1000
# 8/8 - 0s - 5ms/step - loss: 5.7244
# Epoch 109/1000
# 8/8 - 0s - 4ms/step - loss: 5.7077
# Epoch 110/1000
# Generated text:
#  Abeni, curiosity a pito vodka their predictable nation's heal experiences ascent.
#
# 8/8 - 0s - 15ms/step - loss: 5.6935
# Epoch 111/1000
# 8/8 - 0s - 9ms/step - loss: 5.6735
# Epoch 112/1000
# 8/8 - 0s - 9ms/step - loss: 5.6600
# Epoch 113/1000
# 8/8 - 0s - 8ms/step - loss: 5.6435
# Epoch 114/1000
# 8/8 - 0s - 9ms/step - loss: 5.6301
# Epoch 115/1000
# 8/8 - 0s - 6ms/step - loss: 5.6116
# Epoch 116/1000
# 8/8 - 0s - 9ms/step - loss: 5.5986
# Epoch 117/1000
# 8/8 - 0s - 9ms/step - loss: 5.5842
# Epoch 118/1000
# 8/8 - 0s - 5ms/step - loss: 5.5687
# Epoch 119/1000
# 8/8 - 0s - 9ms/step - loss: 5.5538
# Epoch 120/1000
# Generated text:
#  Abeni, infused is horns. glint or Malawi, or pastry, cappella a
#
# 8/8 - 0s - 22ms/step - loss: 5.5388
# Epoch 121/1000
# 8/8 - 0s - 9ms/step - loss: 5.5249
# Epoch 122/1000
# 8/8 - 0s - 5ms/step - loss: 5.5135
# Epoch 123/1000
# 8/8 - 0s - 5ms/step - loss: 5.4963
# Epoch 124/1000
# 8/8 - 0s - 5ms/step - loss: 5.4831
# Epoch 125/1000
# 8/8 - 0s - 5ms/step - loss: 5.4726
# Epoch 126/1000
# 8/8 - 0s - 5ms/step - loss: 5.4562
# Epoch 127/1000
# 8/8 - 0s - 5ms/step - loss: 5.4405
# Epoch 128/1000
# 8/8 - 0s - 9ms/step - loss: 5.4259
# Epoch 129/1000
# 8/8 - 0s - 9ms/step - loss: 5.4132
# Epoch 130/1000
# Generated text:
#  Abeni, textures, falling waterfront (carbohydrates, snack chicken seeds. organs, Senegal from
#
# 8/8 - 0s - 20ms/step - loss: 5.4021
# Epoch 131/1000
# 8/8 - 0s - 9ms/step - loss: 5.3854
# Epoch 132/1000
# 8/8 - 0s - 6ms/step - loss: 5.3694
# Epoch 133/1000
# 8/8 - 0s - 5ms/step - loss: 5.3597
# Epoch 134/1000
# 8/8 - 0s - 5ms/step - loss: 5.3451
# Epoch 135/1000
# 8/8 - 0s - 6ms/step - loss: 5.3363
# Epoch 136/1000
# 8/8 - 0s - 6ms/step - loss: 5.3198
# Epoch 137/1000
# 8/8 - 0s - 9ms/step - loss: 5.3064
# Epoch 138/1000
# 8/8 - 0s - 9ms/step - loss: 5.2950
# Epoch 139/1000
# 8/8 - 0s - 6ms/step - loss: 5.2791
# Epoch 140/1000
# Generated text:
#  Abeni, a prefixes Wolf be Southern African Medina festival, Afrikaans, be
#
# 8/8 - 0s - 23ms/step - loss: 5.2649
# Epoch 141/1000
# 8/8 - 0s - 9ms/step - loss: 5.2545
# Epoch 142/1000
# 8/8 - 0s - 5ms/step - loss: 5.2418
# Epoch 143/1000
# 8/8 - 0s - 9ms/step - loss: 5.2263
# Epoch 144/1000
# 8/8 - 0s - 5ms/step - loss: 5.2144
# Epoch 145/1000
# 8/8 - 0s - 4ms/step - loss: 5.2030
# Epoch 146/1000
# 8/8 - 0s - 5ms/step - loss: 5.1904
# Epoch 147/1000
# 8/8 - 0s - 4ms/step - loss: 5.1766
# Epoch 148/1000
# 8/8 - 0s - 4ms/step - loss: 5.1630
# Epoch 149/1000
# 8/8 - 0s - 4ms/step - loss: 5.1498
# Epoch 150/1000
# Generated text:
#  Abeni, means of Banku soup Fula), across mint the stripes dough
#
# 8/8 - 0s - 15ms/step - loss: 5.1369
# Epoch 151/1000
# 8/8 - 0s - 4ms/step - loss: 5.1264
# Epoch 152/1000
# 8/8 - 0s - 4ms/step - loss: 5.1117
# Epoch 153/1000
# 8/8 - 0s - 4ms/step - loss: 5.1021
# Epoch 154/1000
# 8/8 - 0s - 4ms/step - loss: 5.0878
# Epoch 155/1000
# 8/8 - 0s - 4ms/step - loss: 5.0768
# Epoch 156/1000
# 8/8 - 0s - 8ms/step - loss: 5.0656
# Epoch 157/1000
# 8/8 - 0s - 4ms/step - loss: 5.0536
# Epoch 158/1000
# 8/8 - 0s - 4ms/step - loss: 5.0405
# Epoch 159/1000
# 8/8 - 0s - 4ms/step - loss: 5.0282
# Epoch 160/1000
# Generated text:
#  Abeni, Lagos spoken but from family da South made buzzed went
#
# 8/8 - 0s - 15ms/step - loss: 5.0136
# Epoch 161/1000
# 8/8 - 0s - 4ms/step - loss: 5.0022
# Epoch 162/1000
# 8/8 - 0s - 4ms/step - loss: 4.9913
# Epoch 163/1000
# 8/8 - 0s - 4ms/step - loss: 4.9774
# Epoch 164/1000
# 8/8 - 0s - 5ms/step - loss: 4.9658
# Epoch 165/1000
# 8/8 - 0s - 4ms/step - loss: 4.9542
# Epoch 166/1000
# 8/8 - 0s - 4ms/step - loss: 4.9408
# Epoch 167/1000
# 8/8 - 0s - 4ms/step - loss: 4.9326
# Epoch 168/1000
# 8/8 - 0s - 4ms/step - loss: 4.9173
# Epoch 169/1000
# 8/8 - 0s - 4ms/step - loss: 4.9056
# Epoch 170/1000
# Generated text:
#  Abeni, 'misir spiced geology bitter slices historian, cassava the featuring of
#
# 8/8 - 0s - 15ms/step - loss: 4.8963
# Epoch 171/1000
# 8/8 - 0s - 4ms/step - loss: 4.8830
# Epoch 172/1000
# 8/8 - 0s - 4ms/step - loss: 4.8705
# Epoch 173/1000
# 8/8 - 0s - 4ms/step - loss: 4.8580
# Epoch 174/1000
# 8/8 - 0s - 4ms/step - loss: 4.8497
# Epoch 175/1000
# 8/8 - 0s - 4ms/step - loss: 4.8353
# Epoch 176/1000
# 8/8 - 0s - 4ms/step - loss: 4.8232
# Epoch 177/1000
# 8/8 - 0s - 4ms/step - loss: 4.8102
# Epoch 178/1000
# 8/8 - 0s - 9ms/step - loss: 4.7998
# Epoch 179/1000
# 8/8 - 0s - 4ms/step - loss: 4.7909
# Epoch 180/1000
# Generated text:
#  Abeni, Selamawit, from deterrence. solution tropical thirsty vegetation, traditional most brewed,
#
# 8/8 - 0s - 15ms/step - loss: 4.7771
# Epoch 181/1000
# 8/8 - 0s - 4ms/step - loss: 4.7661
# Epoch 182/1000
# 8/8 - 0s - 4ms/step - loss: 4.7508
# Epoch 183/1000
# 8/8 - 0s - 5ms/step - loss: 4.7397
# Epoch 184/1000
# 8/8 - 0s - 4ms/step - loss: 4.7285
# Epoch 185/1000
# 8/8 - 0s - 5ms/step - loss: 4.7174
# Epoch 186/1000
# 8/8 - 0s - 5ms/step - loss: 4.7048
# Epoch 187/1000
# 8/8 - 0s - 5ms/step - loss: 4.6952
# Epoch 188/1000
# 8/8 - 0s - 4ms/step - loss: 4.6835
# Epoch 189/1000
# 8/8 - 0s - 4ms/step - loss: 4.6698
# Epoch 190/1000
# Generated text:
#  Abeni, library, management, embark to fabric. absorbs several graceful, tissues. lizards.
#
# 8/8 - 0s - 16ms/step - loss: 4.6627
# Epoch 191/1000
# 8/8 - 0s - 4ms/step - loss: 4.6509
# Epoch 192/1000
# 8/8 - 0s - 4ms/step - loss: 4.6415
# Epoch 193/1000
# 8/8 - 0s - 4ms/step - loss: 4.6252
# Epoch 194/1000
# 8/8 - 0s - 4ms/step - loss: 4.6134
# Epoch 195/1000
# 8/8 - 0s - 4ms/step - loss: 4.6052
# Epoch 196/1000
# 8/8 - 0s - 5ms/step - loss: 4.5920
# Epoch 197/1000
# 8/8 - 0s - 5ms/step - loss: 4.5826
# Epoch 198/1000
# 8/8 - 0s - 4ms/step - loss: 4.5716
# Epoch 199/1000
# 8/8 - 0s - 5ms/step - loss: 4.5580
# Epoch 200/1000
# Generated text:
#  Abeni, is Nigeria, Bissap, and the stiff of mammal cold, a
#
# 8/8 - 0s - 16ms/step - loss: 4.5482
# Epoch 201/1000
# 8/8 - 0s - 5ms/step - loss: 4.5352
# Epoch 202/1000
# 8/8 - 0s - 9ms/step - loss: 4.5239
# Epoch 203/1000
# 8/8 - 0s - 4ms/step - loss: 4.5147
# Epoch 204/1000
# 8/8 - 0s - 4ms/step - loss: 4.5070
# Epoch 205/1000
# 8/8 - 0s - 5ms/step - loss: 4.4908
# Epoch 206/1000
# 8/8 - 0s - 5ms/step - loss: 4.4815
# Epoch 207/1000
# 8/8 - 0s - 4ms/step - loss: 4.4689
# Epoch 208/1000
# 8/8 - 0s - 5ms/step - loss: 4.4578
# Epoch 209/1000
# 8/8 - 0s - 4ms/step - loss: 4.4488
# Epoch 210/1000
# Generated text:
#  Abeni, express "pot thick, milky, layer involves alongside Dakar in Nile
#
# 8/8 - 0s - 16ms/step - loss: 4.4364
# Epoch 211/1000
# 8/8 - 0s - 4ms/step - loss: 4.4241
# Epoch 212/1000
# 8/8 - 0s - 5ms/step - loss: 4.4147
# Epoch 213/1000
# 8/8 - 0s - 4ms/step - loss: 4.4018
# Epoch 214/1000
# 8/8 - 0s - 5ms/step - loss: 4.3940
# Epoch 215/1000
# 8/8 - 0s - 5ms/step - loss: 4.3873
# Epoch 216/1000
# 8/8 - 0s - 5ms/step - loss: 4.3730
# Epoch 217/1000
# 8/8 - 0s - 4ms/step - loss: 4.3570
# Epoch 218/1000
# 8/8 - 0s - 5ms/step - loss: 4.3508
# Epoch 219/1000
# 8/8 - 0s - 5ms/step - loss: 4.3395
# Epoch 220/1000
# Generated text:
#  Abeni, a sounds sun finely is beer nation's blended to (Eswatini)
#
# 8/8 - 0s - 20ms/step - loss: 4.3254
# Epoch 221/1000
# 8/8 - 0s - 4ms/step - loss: 4.3163
# Epoch 222/1000
# 8/8 - 0s - 5ms/step - loss: 4.3050
# Epoch 223/1000
# 8/8 - 0s - 5ms/step - loss: 4.2945
# Epoch 224/1000
# 8/8 - 0s - 4ms/step - loss: 4.2832
# Epoch 225/1000
# 8/8 - 0s - 4ms/step - loss: 4.2739
# Epoch 226/1000
# 8/8 - 0s - 4ms/step - loss: 4.2667
# Epoch 227/1000
# 8/8 - 0s - 4ms/step - loss: 4.2558
# Epoch 228/1000
# 8/8 - 0s - 5ms/step - loss: 4.2449
# Epoch 229/1000
# 8/8 - 0s - 4ms/step - loss: 4.2343
# Epoch 230/1000
# Generated text:
#  Abeni, North a girl creamy, East steeped and popular a Niger-Congo
#
# 8/8 - 0s - 15ms/step - loss: 4.2245
# Epoch 231/1000
# 8/8 - 0s - 4ms/step - loss: 4.2108
# Epoch 232/1000
# 8/8 - 0s - 4ms/step - loss: 4.2030
# Epoch 233/1000
# 8/8 - 0s - 4ms/step - loss: 4.1879
# Epoch 234/1000
# 8/8 - 0s - 4ms/step - loss: 4.1812
# Epoch 235/1000
# 8/8 - 0s - 5ms/step - loss: 4.1700
# Epoch 236/1000
# 8/8 - 0s - 4ms/step - loss: 4.1611
# Epoch 237/1000
# 8/8 - 0s - 5ms/step - loss: 4.1491
# Epoch 238/1000
# 8/8 - 0s - 5ms/step - loss: 4.1395
# Epoch 239/1000
# 8/8 - 0s - 4ms/step - loss: 4.1298
# Epoch 240/1000
# Generated text:
#  Abeni, highlights climate, is a sausage one semolina drove African Wat,
#
# 8/8 - 0s - 17ms/step - loss: 4.1200
# Epoch 241/1000
# 8/8 - 0s - 4ms/step - loss: 4.1112
# Epoch 242/1000
# 8/8 - 0s - 4ms/step - loss: 4.1010
# Epoch 243/1000
# 8/8 - 0s - 4ms/step - loss: 4.0875
# Epoch 244/1000
# 8/8 - 0s - 4ms/step - loss: 4.0796
# Epoch 245/1000
# 8/8 - 0s - 4ms/step - loss: 4.0711
# Epoch 246/1000
# 8/8 - 0s - 4ms/step - loss: 4.0580
# Epoch 247/1000
# 8/8 - 0s - 4ms/step - loss: 4.0481
# Epoch 248/1000
# 8/8 - 0s - 5ms/step - loss: 4.0390
# Epoch 249/1000
# 8/8 - 0s - 4ms/step - loss: 4.0286
# Epoch 250/1000
# Generated text:
#  Abeni, down a creature Kenya had fermented wrapped on looking tea
#
# 8/8 - 0s - 16ms/step - loss: 4.0169
# Epoch 251/1000
# 8/8 - 0s - 4ms/step - loss: 4.0042
# Epoch 252/1000
# 8/8 - 0s - 4ms/step - loss: 3.9966
# Epoch 253/1000
# 8/8 - 0s - 5ms/step - loss: 3.9876
# Epoch 254/1000
# 8/8 - 0s - 5ms/step - loss: 3.9779
# Epoch 255/1000
# 8/8 - 0s - 5ms/step - loss: 3.9693
# Epoch 256/1000
# 8/8 - 0s - 5ms/step - loss: 3.9570
# Epoch 257/1000
# 8/8 - 0s - 5ms/step - loss: 3.9517
# Epoch 258/1000
# 8/8 - 0s - 5ms/step - loss: 3.9404
# Epoch 259/1000
# 8/8 - 0s - 5ms/step - loss: 3.9299
# Epoch 260/1000
# Generated text:
#  Abeni, National delightful infused chow adapted afternoon, southern extracted of night
#
# 8/8 - 0s - 16ms/step - loss: 3.9201
# Epoch 261/1000
# 8/8 - 0s - 5ms/step - loss: 3.9103
# Epoch 262/1000
# 8/8 - 0s - 4ms/step - loss: 3.9041
# Epoch 263/1000
# 8/8 - 0s - 5ms/step - loss: 3.8928
# Epoch 264/1000
# 8/8 - 0s - 5ms/step - loss: 3.8795
# Epoch 265/1000
# 8/8 - 0s - 5ms/step - loss: 3.8712
# Epoch 266/1000
# 8/8 - 0s - 5ms/step - loss: 3.8588
# Epoch 267/1000
# 8/8 - 0s - 5ms/step - loss: 3.8487
# Epoch 268/1000
# 8/8 - 0s - 4ms/step - loss: 3.8425
# Epoch 269/1000
# 8/8 - 0s - 5ms/step - loss: 3.8329
# Epoch 270/1000
# Generated text:
#  Abeni, a is a vast, West choices Middle portion birds city
#
# 8/8 - 0s - 15ms/step - loss: 3.8239
# Epoch 271/1000
# 8/8 - 0s - 4ms/step - loss: 3.8143
# Epoch 272/1000
# 8/8 - 0s - 4ms/step - loss: 3.8047
# Epoch 273/1000
# 8/8 - 0s - 4ms/step - loss: 3.7954
# Epoch 274/1000
# 8/8 - 0s - 4ms/step - loss: 3.7891
# Epoch 275/1000
# 8/8 - 0s - 5ms/step - loss: 3.7801
# Epoch 276/1000
# 8/8 - 0s - 4ms/step - loss: 3.7684
# Epoch 277/1000
# 8/8 - 0s - 4ms/step - loss: 3.7598
# Epoch 278/1000
# 8/8 - 0s - 4ms/step - loss: 3.7513
# Epoch 279/1000
# 8/8 - 0s - 5ms/step - loss: 3.7409
# Epoch 280/1000
# Generated text:
#  Abeni, a sculpture, from Doro kachumbari the enjoy a and traditional
#
# 8/8 - 0s - 15ms/step - loss: 3.7293
# Epoch 281/1000
# 8/8 - 0s - 4ms/step - loss: 3.7216
# Epoch 282/1000
# 8/8 - 0s - 5ms/step - loss: 3.7130
# Epoch 283/1000
# 8/8 - 0s - 5ms/step - loss: 3.7033
# Epoch 284/1000
# 8/8 - 0s - 4ms/step - loss: 3.6952
# Epoch 285/1000
# 8/8 - 0s - 5ms/step - loss: 3.6855
# Epoch 286/1000
# 8/8 - 0s - 5ms/step - loss: 3.6752
# Epoch 287/1000
# 8/8 - 0s - 5ms/step - loss: 3.6713
# Epoch 288/1000
# 8/8 - 0s - 5ms/step - loss: 3.6598
# Epoch 289/1000
# 8/8 - 0s - 5ms/step - loss: 3.6511
# Epoch 290/1000
# Generated text:
#  Abeni, Sahara with a pigeon kudu Marrakech stew long nights. non-alcoholic
#
# 8/8 - 0s - 16ms/step - loss: 3.6434
# Epoch 291/1000
# 8/8 - 0s - 4ms/step - loss: 3.6341
# Epoch 292/1000
# 8/8 - 0s - 4ms/step - loss: 3.6220
# Epoch 293/1000
# 8/8 - 0s - 5ms/step - loss: 3.6128
# Epoch 294/1000
# 8/8 - 0s - 5ms/step - loss: 3.6082
# Epoch 295/1000
# 8/8 - 0s - 5ms/step - loss: 3.5951
# Epoch 296/1000
# 8/8 - 0s - 5ms/step - loss: 3.5891
# Epoch 297/1000
# 8/8 - 0s - 4ms/step - loss: 3.5812
# Epoch 298/1000
# 8/8 - 0s - 5ms/step - loss: 3.5728
# Epoch 299/1000
# 8/8 - 0s - 4ms/step - loss: 3.5631
# Epoch 300/1000
# Generated text:
#  Abeni, a boy Dakar camouflage bustling in maize is Africa's a
#
# 8/8 - 0s - 15ms/step - loss: 3.5575
# Epoch 301/1000
# 8/8 - 0s - 4ms/step - loss: 3.5454
# Epoch 302/1000
# 8/8 - 0s - 4ms/step - loss: 3.5364
# Epoch 303/1000
# 8/8 - 0s - 4ms/step - loss: 3.5286
# Epoch 304/1000
# 8/8 - 0s - 4ms/step - loss: 3.5209
# Epoch 305/1000
# 8/8 - 0s - 5ms/step - loss: 3.5090
# Epoch 306/1000
# 8/8 - 0s - 5ms/step - loss: 3.5027
# Epoch 307/1000
# 8/8 - 0s - 5ms/step - loss: 3.4947
# Epoch 308/1000
# 8/8 - 0s - 5ms/step - loss: 3.4888
# Epoch 309/1000
# 8/8 - 0s - 4ms/step - loss: 3.4792
# Epoch 310/1000
# Generated text:
#  Abeni, a fruit, fluid of the frequent Earth, a fermented from
#
# 8/8 - 0s - 15ms/step - loss: 3.4693
# Epoch 311/1000
# 8/8 - 0s - 4ms/step - loss: 3.4600
# Epoch 312/1000
# 8/8 - 0s - 4ms/step - loss: 3.4558
# Epoch 313/1000
# 8/8 - 0s - 5ms/step - loss: 3.4438
# Epoch 314/1000
# 8/8 - 0s - 5ms/step - loss: 3.4370
# Epoch 315/1000
# 8/8 - 0s - 5ms/step - loss: 3.4289
# Epoch 316/1000
# 8/8 - 0s - 5ms/step - loss: 3.4166
# Epoch 317/1000
# 8/8 - 0s - 5ms/step - loss: 3.4102
# Epoch 318/1000
# 8/8 - 0s - 5ms/step - loss: 3.4051
# Epoch 319/1000
# 8/8 - 0s - 5ms/step - loss: 3.3983
# Epoch 320/1000
# Generated text:
#  Abeni, a comforting Mediterranean renowned trove adorned hibiscus large, Africa, was
#
# 8/8 - 0s - 15ms/step - loss: 3.3868
# Epoch 321/1000
# 8/8 - 0s - 4ms/step - loss: 3.3791
# Epoch 322/1000
# 8/8 - 0s - 5ms/step - loss: 3.3733
# Epoch 323/1000
# 8/8 - 0s - 5ms/step - loss: 3.3625
# Epoch 324/1000
# 8/8 - 0s - 4ms/step - loss: 3.3541
# Epoch 325/1000
# 8/8 - 0s - 4ms/step - loss: 3.3490
# Epoch 326/1000
# 8/8 - 0s - 5ms/step - loss: 3.3394
# Epoch 327/1000
# 8/8 - 0s - 5ms/step - loss: 3.3297
# Epoch 328/1000
# 8/8 - 0s - 4ms/step - loss: 3.3236
# Epoch 329/1000
# 8/8 - 0s - 4ms/step - loss: 3.3143
# Epoch 330/1000
# Generated text:
#  Abeni, a group of him to the Senegalese dried and to
#
# 8/8 - 0s - 16ms/step - loss: 3.3061
# Epoch 331/1000
# 8/8 - 0s - 4ms/step - loss: 3.3008
# Epoch 332/1000
# 8/8 - 0s - 4ms/step - loss: 3.2922
# Epoch 333/1000
# 8/8 - 0s - 4ms/step - loss: 3.2849
# Epoch 334/1000
# 8/8 - 0s - 4ms/step - loss: 3.2783
# Epoch 335/1000
# 8/8 - 0s - 5ms/step - loss: 3.2688
# Epoch 336/1000
# 8/8 - 0s - 5ms/step - loss: 3.2612
# Epoch 337/1000
# 8/8 - 0s - 5ms/step - loss: 3.2564
# Epoch 338/1000
# 8/8 - 0s - 5ms/step - loss: 3.2475
# Epoch 339/1000
# 8/8 - 0s - 5ms/step - loss: 3.2410
# Epoch 340/1000
# Generated text:
#  Abeni, a involves Kilimanjaro, a grilled Congolese a caffeine-free beer Abidjan
#
# 8/8 - 0s - 16ms/step - loss: 3.2310
# Epoch 341/1000
# 8/8 - 0s - 4ms/step - loss: 3.2272
# Epoch 342/1000
# 8/8 - 0s - 4ms/step - loss: 3.2165
# Epoch 343/1000
# 8/8 - 0s - 5ms/step - loss: 3.2101
# Epoch 344/1000
# 8/8 - 0s - 4ms/step - loss: 3.2005
# Epoch 345/1000
# 8/8 - 0s - 5ms/step - loss: 3.1938
# Epoch 346/1000
# 8/8 - 0s - 5ms/step - loss: 3.1895
# Epoch 347/1000
# 8/8 - 0s - 5ms/step - loss: 3.1801
# Epoch 348/1000
# 8/8 - 0s - 5ms/step - loss: 3.1717
# Epoch 349/1000
# 8/8 - 0s - 5ms/step - loss: 3.1652
# Epoch 350/1000
# Generated text:
#  Abeni, a fish, a bright role in a men, heat, modern-day
#
# 8/8 - 0s - 15ms/step - loss: 3.1556
# Epoch 351/1000
# 8/8 - 0s - 9ms/step - loss: 3.1519
# Epoch 352/1000
# 8/8 - 0s - 6ms/step - loss: 3.1423
# Epoch 353/1000
# 8/8 - 0s - 4ms/step - loss: 3.1364
# Epoch 354/1000
# 8/8 - 0s - 9ms/step - loss: 3.1251
# Epoch 355/1000
# 8/8 - 0s - 5ms/step - loss: 3.1190
# Epoch 356/1000
# 8/8 - 0s - 5ms/step - loss: 3.1144
# Epoch 357/1000
# 8/8 - 0s - 6ms/step - loss: 3.1033
# Epoch 358/1000
# 8/8 - 0s - 9ms/step - loss: 3.1010
# Epoch 359/1000
# 8/8 - 0s - 5ms/step - loss: 3.0956
# Epoch 360/1000
# Generated text:
#  Abeni, a boy of a known men can different garments, transitional
#
# 8/8 - 0s - 25ms/step - loss: 3.0844
# Epoch 361/1000
# 8/8 - 0s - 9ms/step - loss: 3.0788
# Epoch 362/1000
# 8/8 - 0s - 9ms/step - loss: 3.0741
# Epoch 363/1000
# 8/8 - 0s - 9ms/step - loss: 3.0617
# Epoch 364/1000
# 8/8 - 0s - 9ms/step - loss: 3.0580
# Epoch 365/1000
# 8/8 - 0s - 5ms/step - loss: 3.0487
# Epoch 366/1000
# 8/8 - 0s - 9ms/step - loss: 3.0429
# Epoch 367/1000
# 8/8 - 0s - 9ms/step - loss: 3.0394
# Epoch 368/1000
# 8/8 - 0s - 9ms/step - loss: 3.0319
# Epoch 369/1000
# 8/8 - 0s - 9ms/step - loss: 3.0222
# Epoch 370/1000
# Generated text:
#  Abeni, a hot was thirsty so as the “tied mangoes land
#
# 8/8 - 0s - 20ms/step - loss: 3.0140
# Epoch 371/1000
# 8/8 - 0s - 7ms/step - loss: 3.0088
# Epoch 372/1000
# 8/8 - 0s - 6ms/step - loss: 3.0013
# Epoch 373/1000
# 8/8 - 0s - 9ms/step - loss: 2.9953
# Epoch 374/1000
# 8/8 - 0s - 9ms/step - loss: 2.9878
# Epoch 375/1000
# 8/8 - 0s - 5ms/step - loss: 2.9851
# Epoch 376/1000
# 8/8 - 0s - 5ms/step - loss: 2.9761
# Epoch 377/1000
# 8/8 - 0s - 5ms/step - loss: 2.9671
# Epoch 378/1000
# 8/8 - 0s - 6ms/step - loss: 2.9635
# Epoch 379/1000
# 8/8 - 0s - 6ms/step - loss: 2.9568
# Epoch 380/1000
# Generated text:
#  Abeni, a strenuous air freshwater made of Malawi, and Having dish
#
# 8/8 - 0s - 22ms/step - loss: 2.9486
# Epoch 381/1000
# 8/8 - 0s - 9ms/step - loss: 2.9428
# Epoch 382/1000
# 8/8 - 0s - 4ms/step - loss: 2.9337
# Epoch 383/1000
# 8/8 - 0s - 5ms/step - loss: 2.9293
# Epoch 384/1000
# 8/8 - 0s - 4ms/step - loss: 2.9220
# Epoch 385/1000
# 8/8 - 0s - 4ms/step - loss: 2.9137
# Epoch 386/1000
# 8/8 - 0s - 4ms/step - loss: 2.9089
# Epoch 387/1000
# 8/8 - 0s - 4ms/step - loss: 2.9008
# Epoch 388/1000
# 8/8 - 0s - 4ms/step - loss: 2.8938
# Epoch 389/1000
# 8/8 - 0s - 4ms/step - loss: 2.8865
# Epoch 390/1000
# Generated text:
#  Abeni, a German village UNESCO Marrakech, onions land region, a a
#
# 8/8 - 0s - 15ms/step - loss: 2.8802
# Epoch 391/1000
# 8/8 - 0s - 4ms/step - loss: 2.8705
# Epoch 392/1000
# 8/8 - 0s - 4ms/step - loss: 2.8687
# Epoch 393/1000
# 8/8 - 0s - 5ms/step - loss: 2.8587
# Epoch 394/1000
# 8/8 - 0s - 4ms/step - loss: 2.8557
# Epoch 395/1000
# 8/8 - 0s - 5ms/step - loss: 2.8495
# Epoch 396/1000
# 8/8 - 0s - 5ms/step - loss: 2.8428
# Epoch 397/1000
# 8/8 - 0s - 4ms/step - loss: 2.8363
# Epoch 398/1000
# 8/8 - 0s - 4ms/step - loss: 2.8297
# Epoch 399/1000
# 8/8 - 0s - 5ms/step - loss: 2.8254
# Epoch 400/1000
# Generated text:
#  Abeni, a trees rice are miniature shopping known as pine adventurer
#
# 8/8 - 0s - 15ms/step - loss: 2.8194
# Epoch 401/1000
# 8/8 - 0s - 4ms/step - loss: 2.8111
# Epoch 402/1000
# 8/8 - 0s - 4ms/step - loss: 2.8069
# Epoch 403/1000
# 8/8 - 0s - 4ms/step - loss: 2.7967
# Epoch 404/1000
# 8/8 - 0s - 5ms/step - loss: 2.7905
# Epoch 405/1000
# 8/8 - 0s - 4ms/step - loss: 2.7854
# Epoch 406/1000
# 8/8 - 0s - 4ms/step - loss: 2.7800
# Epoch 407/1000
# 8/8 - 0s - 4ms/step - loss: 2.7722
# Epoch 408/1000
# 8/8 - 0s - 4ms/step - loss: 2.7636
# Epoch 409/1000
# 8/8 - 0s - 5ms/step - loss: 2.7638
# Epoch 410/1000
# Generated text:
#  Abeni, a beloved plantains role in southern continent. of the Cow's
#
# 8/8 - 0s - 15ms/step - loss: 2.7539
# Epoch 411/1000
# 8/8 - 0s - 4ms/step - loss: 2.7485
# Epoch 412/1000
# 8/8 - 0s - 4ms/step - loss: 2.7453
# Epoch 413/1000
# 8/8 - 0s - 5ms/step - loss: 2.7375
# Epoch 414/1000
# 8/8 - 0s - 5ms/step - loss: 2.7307
# Epoch 415/1000
# 8/8 - 0s - 5ms/step - loss: 2.7252
# Epoch 416/1000
# 8/8 - 0s - 5ms/step - loss: 2.7195
# Epoch 417/1000
# 8/8 - 0s - 5ms/step - loss: 2.7144
# Epoch 418/1000
# 8/8 - 0s - 5ms/step - loss: 2.7097
# Epoch 419/1000
# 8/8 - 0s - 5ms/step - loss: 2.7005
# Epoch 420/1000
# Generated text:
#  Abeni, a famous men on Thabo's light looking peak and the
#
# 8/8 - 0s - 16ms/step - loss: 2.6919
# Epoch 421/1000
# 8/8 - 0s - 4ms/step - loss: 2.6902
# Epoch 422/1000
# 8/8 - 0s - 4ms/step - loss: 2.6831
# Epoch 423/1000
# 8/8 - 0s - 4ms/step - loss: 2.6759
# Epoch 424/1000
# 8/8 - 0s - 4ms/step - loss: 2.6693
# Epoch 425/1000
# 8/8 - 0s - 5ms/step - loss: 2.6611
# Epoch 426/1000
# 8/8 - 0s - 5ms/step - loss: 2.6585
# Epoch 427/1000
# 8/8 - 0s - 5ms/step - loss: 2.6528
# Epoch 428/1000
# 8/8 - 0s - 5ms/step - loss: 2.6475
# Epoch 429/1000
# 8/8 - 0s - 5ms/step - loss: 2.6404
# Epoch 430/1000
# Generated text:
#  Abeni, a traditional magnesium, grasping a vast, milky, dressed went in
#
# 8/8 - 0s - 15ms/step - loss: 2.6348
# Epoch 431/1000
# 8/8 - 0s - 4ms/step - loss: 2.6290
# Epoch 432/1000
# 8/8 - 0s - 4ms/step - loss: 2.6229
# Epoch 433/1000
# 8/8 - 0s - 5ms/step - loss: 2.6160
# Epoch 434/1000
# 8/8 - 0s - 5ms/step - loss: 2.6119
# Epoch 435/1000
# 8/8 - 0s - 5ms/step - loss: 2.6059
# Epoch 436/1000
# 8/8 - 0s - 5ms/step - loss: 2.5994
# Epoch 437/1000
# 8/8 - 0s - 5ms/step - loss: 2.5944
# Epoch 438/1000
# 8/8 - 0s - 5ms/step - loss: 2.5859
# Epoch 439/1000
# 8/8 - 0s - 5ms/step - loss: 2.5819
# Epoch 440/1000
# Generated text:
#  Abeni, a colors and Rich is a staple the fruit horses
#
# 8/8 - 0s - 17ms/step - loss: 2.5799
# Epoch 441/1000
# 8/8 - 0s - 4ms/step - loss: 2.5672
# Epoch 442/1000
# 8/8 - 0s - 5ms/step - loss: 2.5672
# Epoch 443/1000
# 8/8 - 0s - 5ms/step - loss: 2.5611
# Epoch 444/1000
# 8/8 - 0s - 5ms/step - loss: 2.5523
# Epoch 445/1000
# 8/8 - 0s - 5ms/step - loss: 2.5470
# Epoch 446/1000
# 8/8 - 0s - 5ms/step - loss: 2.5434
# Epoch 447/1000
# 8/8 - 0s - 5ms/step - loss: 2.5379
# Epoch 448/1000
# 8/8 - 0s - 5ms/step - loss: 2.5317
# Epoch 449/1000
# 8/8 - 0s - 5ms/step - loss: 2.5252
# Epoch 450/1000
# Generated text:
#  Abeni, a reading Adire, adorned with prides, by and a the
#
# 8/8 - 0s - 15ms/step - loss: 2.5201
# Epoch 451/1000
# 8/8 - 0s - 4ms/step - loss: 2.5164
# Epoch 452/1000
# 8/8 - 0s - 4ms/step - loss: 2.5082
# Epoch 453/1000
# 8/8 - 0s - 5ms/step - loss: 2.5026
# Epoch 454/1000
# 8/8 - 0s - 5ms/step - loss: 2.4960
# Epoch 455/1000
# 8/8 - 0s - 5ms/step - loss: 2.4906
# Epoch 456/1000
# 8/8 - 0s - 5ms/step - loss: 2.4864
# Epoch 457/1000
# 8/8 - 0s - 5ms/step - loss: 2.4813
# Epoch 458/1000
# 8/8 - 0s - 5ms/step - loss: 2.4758
# Epoch 459/1000
# 8/8 - 0s - 5ms/step - loss: 2.4687
# Epoch 460/1000
# Generated text:
#  Abeni, a flavorful fought, is a Ami, the flat-topped of seemingly
#
# 8/8 - 0s - 15ms/step - loss: 2.4654
# Epoch 461/1000
# 8/8 - 0s - 5ms/step - loss: 2.4568
# Epoch 462/1000
# 8/8 - 0s - 4ms/step - loss: 2.4540
# Epoch 463/1000
# 8/8 - 0s - 4ms/step - loss: 2.4478
# Epoch 464/1000
# 8/8 - 0s - 5ms/step - loss: 2.4423
# Epoch 465/1000
# 8/8 - 0s - 4ms/step - loss: 2.4382
# Epoch 466/1000
# 8/8 - 0s - 5ms/step - loss: 2.4339
# Epoch 467/1000
# 8/8 - 0s - 5ms/step - loss: 2.4256
# Epoch 468/1000
# 8/8 - 0s - 5ms/step - loss: 2.4198
# Epoch 469/1000
# 8/8 - 0s - 5ms/step - loss: 2.4150
# Epoch 470/1000
# Generated text:
#  Abeni, a casting diffusion in fingers, Nigeria, Kenyan is a a
#
# 8/8 - 0s - 15ms/step - loss: 2.4104
# Epoch 471/1000
# 8/8 - 0s - 4ms/step - loss: 2.4056
# Epoch 472/1000
# 8/8 - 0s - 4ms/step - loss: 2.3992
# Epoch 473/1000
# 8/8 - 0s - 5ms/step - loss: 2.3956
# Epoch 474/1000
# 8/8 - 0s - 5ms/step - loss: 2.3922
# Epoch 475/1000
# 8/8 - 0s - 5ms/step - loss: 2.3805
# Epoch 476/1000
# 8/8 - 0s - 5ms/step - loss: 2.3771
# Epoch 477/1000
# 8/8 - 0s - 5ms/step - loss: 2.3754
# Epoch 478/1000
# 8/8 - 0s - 5ms/step - loss: 2.3676
# Epoch 479/1000
# 8/8 - 0s - 5ms/step - loss: 2.3620
# Epoch 480/1000
# Generated text:
#  Abeni, a popular in Falls, a Egyptian Akosua fermented blended looking
#
# 8/8 - 0s - 16ms/step - loss: 2.3554
# Epoch 481/1000
# 8/8 - 0s - 4ms/step - loss: 2.3540
# Epoch 482/1000
# 8/8 - 0s - 4ms/step - loss: 2.3471
# Epoch 483/1000
# 8/8 - 0s - 6ms/step - loss: 2.3440
# Epoch 484/1000
# 8/8 - 0s - 4ms/step - loss: 2.3363
# Epoch 485/1000
# 8/8 - 0s - 5ms/step - loss: 2.3304
# Epoch 486/1000
# 8/8 - 0s - 4ms/step - loss: 2.3259
# Epoch 487/1000
# 8/8 - 0s - 5ms/step - loss: 2.3218
# Epoch 488/1000
# 8/8 - 0s - 5ms/step - loss: 2.3138
# Epoch 489/1000
# 8/8 - 0s - 5ms/step - loss: 2.3113
# Epoch 490/1000
# Generated text:
#  Abeni, but light, during consuming a bustling concentration. as cassava dish
#
# 8/8 - 0s - 15ms/step - loss: 2.3050
# Epoch 491/1000
# 8/8 - 0s - 4ms/step - loss: 2.2986
# Epoch 492/1000
# 8/8 - 0s - 4ms/step - loss: 2.2984
# Epoch 493/1000
# 8/8 - 0s - 5ms/step - loss: 2.2879
# Epoch 494/1000
# 8/8 - 0s - 4ms/step - loss: 2.2850
# Epoch 495/1000
# 8/8 - 0s - 4ms/step - loss: 2.2794
# Epoch 496/1000
# 8/8 - 0s - 5ms/step - loss: 2.2728
# Epoch 497/1000
# 8/8 - 0s - 5ms/step - loss: 2.2689
# Epoch 498/1000
# 8/8 - 0s - 4ms/step - loss: 2.2650
# Epoch 499/1000
# 8/8 - 0s - 5ms/step - loss: 2.2616
# Epoch 500/1000
# Generated text:
#  Abeni, a creamy, (also 1000 went warmth, length, was went she
#
# 8/8 - 0s - 16ms/step - loss: 2.2552
# Epoch 501/1000
# 8/8 - 0s - 5ms/step - loss: 2.2501
# Epoch 502/1000
# 8/8 - 0s - 4ms/step - loss: 2.2436
# Epoch 503/1000
# 8/8 - 0s - 5ms/step - loss: 2.2418
# Epoch 504/1000
# 8/8 - 0s - 9ms/step - loss: 2.2347
# Epoch 505/1000
# 8/8 - 0s - 6ms/step - loss: 2.2313
# Epoch 506/1000
# 8/8 - 0s - 4ms/step - loss: 2.2252
# Epoch 507/1000
# 8/8 - 0s - 4ms/step - loss: 2.2180
# Epoch 508/1000
# 8/8 - 0s - 5ms/step - loss: 2.2152
# Epoch 509/1000
# 8/8 - 0s - 4ms/step - loss: 2.2124
# Epoch 510/1000
# Generated text:
#  Abeni, a dressed of distinctive engaged and the afternoon tea Fura
#
# 8/8 - 0s - 16ms/step - loss: 2.2074
# Epoch 511/1000
# 8/8 - 0s - 5ms/step - loss: 2.2008
# Epoch 512/1000
# 8/8 - 0s - 4ms/step - loss: 2.1980
# Epoch 513/1000
# 8/8 - 0s - 4ms/step - loss: 2.1908
# Epoch 514/1000
# 8/8 - 0s - 4ms/step - loss: 2.1886
# Epoch 515/1000
# 8/8 - 0s - 5ms/step - loss: 2.1825
# Epoch 516/1000
# 8/8 - 0s - 4ms/step - loss: 2.1787
# Epoch 517/1000
# 8/8 - 0s - 4ms/step - loss: 2.1773
# Epoch 518/1000
# 8/8 - 0s - 5ms/step - loss: 2.1677
# Epoch 519/1000
# 8/8 - 0s - 5ms/step - loss: 2.1620
# Epoch 520/1000
# Generated text:
#  Abeni, a dish considered soft Mozambique, is a from Moroccan Xhosa),
#
# 8/8 - 0s - 16ms/step - loss: 2.1580
# Epoch 521/1000
# 8/8 - 0s - 4ms/step - loss: 2.1522
# Epoch 522/1000
# 8/8 - 0s - 4ms/step - loss: 2.1449
# Epoch 523/1000
# 8/8 - 0s - 5ms/step - loss: 2.1454
# Epoch 524/1000
# 8/8 - 0s - 5ms/step - loss: 2.1373
# Epoch 525/1000
# 8/8 - 0s - 5ms/step - loss: 2.1341
# Epoch 526/1000
# 8/8 - 0s - 4ms/step - loss: 2.1299
# Epoch 527/1000
# 8/8 - 0s - 5ms/step - loss: 2.1234
# Epoch 528/1000
# 8/8 - 0s - 5ms/step - loss: 2.1208
# Epoch 529/1000
# 8/8 - 0s - 5ms/step - loss: 2.1116
# Epoch 530/1000
# Generated text:
#  Abeni, a African sought avocados, stars modern-day goldweights, furrowed that rice
#
# 8/8 - 0s - 15ms/step - loss: 2.1111
# Epoch 531/1000
# 8/8 - 0s - 4ms/step - loss: 2.1054
# Epoch 532/1000
# 8/8 - 0s - 4ms/step - loss: 2.0993
# Epoch 533/1000
# 8/8 - 0s - 5ms/step - loss: 2.0989
# Epoch 534/1000
# 8/8 - 0s - 5ms/step - loss: 2.0911
# Epoch 535/1000
# 8/8 - 0s - 5ms/step - loss: 2.0889
# Epoch 536/1000
# 8/8 - 0s - 5ms/step - loss: 2.0821
# Epoch 537/1000
# 8/8 - 0s - 5ms/step - loss: 2.0760
# Epoch 538/1000
# 8/8 - 0s - 5ms/step - loss: 2.0711
# Epoch 539/1000
# 8/8 - 0s - 5ms/step - loss: 2.0661
# Epoch 540/1000
# Generated text:
#  Abeni, a Ghanaian sun headscarf, maize the hard of furniture, categorize
#
# 8/8 - 0s - 16ms/step - loss: 2.0646
# Epoch 541/1000
# 8/8 - 0s - 4ms/step - loss: 2.0557
# Epoch 542/1000
# 8/8 - 0s - 4ms/step - loss: 2.0524
# Epoch 543/1000
# 8/8 - 0s - 5ms/step - loss: 2.0516
# Epoch 544/1000
# 8/8 - 0s - 5ms/step - loss: 2.0448
# Epoch 545/1000
# 8/8 - 0s - 5ms/step - loss: 2.0379
# Epoch 546/1000
# 8/8 - 0s - 5ms/step - loss: 2.0357
# Epoch 547/1000
# 8/8 - 0s - 4ms/step - loss: 2.0306
# Epoch 548/1000
# 8/8 - 0s - 5ms/step - loss: 2.0265
# Epoch 549/1000
# 8/8 - 0s - 5ms/step - loss: 2.0209
# Epoch 550/1000
# Generated text:
#  Abeni, a long located in non-alcoholic extremely spoken and Nigeria, Fura
#
# 8/8 - 0s - 15ms/step - loss: 2.0181
# Epoch 551/1000
# 8/8 - 0s - 4ms/step - loss: 2.0129
# Epoch 552/1000
# 8/8 - 0s - 5ms/step - loss: 2.0107
# Epoch 553/1000
# 8/8 - 0s - 5ms/step - loss: 2.0060
# Epoch 554/1000
# 8/8 - 0s - 5ms/step - loss: 2.0018
# Epoch 555/1000
# 8/8 - 0s - 5ms/step - loss: 1.9958
# Epoch 556/1000
# 8/8 - 0s - 5ms/step - loss: 1.9877
# Epoch 557/1000
# 8/8 - 0s - 5ms/step - loss: 1.9886
# Epoch 558/1000
# 8/8 - 0s - 4ms/step - loss: 1.9827
# Epoch 559/1000
# 8/8 - 0s - 5ms/step - loss: 1.9749
# Epoch 560/1000
# Generated text:
#  Abeni, a female. name with a lion (60 impala Moroccan ambitious
#
# 8/8 - 0s - 16ms/step - loss: 1.9713
# Epoch 561/1000
# 8/8 - 0s - 4ms/step - loss: 1.9717
# Epoch 562/1000
# 8/8 - 0s - 4ms/step - loss: 1.9651
# Epoch 563/1000
# 8/8 - 0s - 4ms/step - loss: 1.9644
# Epoch 564/1000
# 8/8 - 0s - 5ms/step - loss: 1.9593
# Epoch 565/1000
# 8/8 - 0s - 5ms/step - loss: 1.9514
# Epoch 566/1000
# 8/8 - 0s - 5ms/step - loss: 1.9465
# Epoch 567/1000
# 8/8 - 0s - 5ms/step - loss: 1.9410
# Epoch 568/1000
# 8/8 - 0s - 5ms/step - loss: 1.9399
# Epoch 569/1000
# 8/8 - 0s - 5ms/step - loss: 1.9337
# Epoch 570/1000
# Generated text:
#  Abeni, a diverse purposes. we night one of the staple for
#
# 8/8 - 0s - 16ms/step - loss: 1.9318
# Epoch 571/1000
# 8/8 - 0s - 4ms/step - loss: 1.9271
# Epoch 572/1000
# 8/8 - 0s - 4ms/step - loss: 1.9195
# Epoch 573/1000
# 8/8 - 0s - 4ms/step - loss: 1.9167
# Epoch 574/1000
# 8/8 - 0s - 4ms/step - loss: 1.9147
# Epoch 575/1000
# 8/8 - 0s - 5ms/step - loss: 1.9043
# Epoch 576/1000
# 8/8 - 0s - 5ms/step - loss: 1.9048
# Epoch 577/1000
# 8/8 - 0s - 5ms/step - loss: 1.9039
# Epoch 578/1000
# 8/8 - 0s - 5ms/step - loss: 1.8951
# Epoch 579/1000
# 8/8 - 0s - 5ms/step - loss: 1.8927
# Epoch 580/1000
# Generated text:
#  Abeni, a Chinedu, (mead). Okavango Baobab in. 'king the South liqueur
#
# 8/8 - 0s - 15ms/step - loss: 1.8886
# Epoch 581/1000
# 8/8 - 0s - 4ms/step - loss: 1.8838
# Epoch 582/1000
# 8/8 - 0s - 4ms/step - loss: 1.8787
# Epoch 583/1000
# 8/8 - 0s - 5ms/step - loss: 1.8746
# Epoch 584/1000
# 8/8 - 0s - 5ms/step - loss: 1.8708
# Epoch 585/1000
# 8/8 - 0s - 5ms/step - loss: 1.8674
# Epoch 586/1000
# 8/8 - 0s - 5ms/step - loss: 1.8641
# Epoch 587/1000
# 8/8 - 0s - 5ms/step - loss: 1.8593
# Epoch 588/1000
# 8/8 - 0s - 9ms/step - loss: 1.8542
# Epoch 589/1000
# 8/8 - 0s - 7ms/step - loss: 1.8499
# Epoch 590/1000
# Generated text:
#  Abeni, a major mother, tube in East African labels, Accra food"
#
# 8/8 - 0s - 25ms/step - loss: 1.8460
# Epoch 591/1000
# 8/8 - 0s - 6ms/step - loss: 1.8433
# Epoch 592/1000
# 8/8 - 0s - 9ms/step - loss: 1.8380
# Epoch 593/1000
# 8/8 - 0s - 5ms/step - loss: 1.8314
# Epoch 594/1000
# 8/8 - 0s - 9ms/step - loss: 1.8271
# Epoch 595/1000
# 8/8 - 0s - 9ms/step - loss: 1.8231
# Epoch 596/1000
# 8/8 - 0s - 5ms/step - loss: 1.8214
# Epoch 597/1000
# 8/8 - 0s - 9ms/step - loss: 1.8156
# Epoch 598/1000
# 8/8 - 0s - 9ms/step - loss: 1.8143
# Epoch 599/1000
# 8/8 - 0s - 9ms/step - loss: 1.8069
# Epoch 600/1000
# Generated text:
#  Abeni, a humidity, porous development. bowl top, is a zone sun
#
# 8/8 - 0s - 25ms/step - loss: 1.8066
# Epoch 601/1000
# 8/8 - 0s - 9ms/step - loss: 1.8010
# Epoch 602/1000
# 8/8 - 0s - 5ms/step - loss: 1.7976
# Epoch 603/1000
# 8/8 - 0s - 9ms/step - loss: 1.7921
# Epoch 604/1000
# 8/8 - 0s - 5ms/step - loss: 1.7895
# Epoch 605/1000
# 8/8 - 0s - 5ms/step - loss: 1.7848
# Epoch 606/1000
# 8/8 - 0s - 9ms/step - loss: 1.7800
# Epoch 607/1000
# 8/8 - 0s - 5ms/step - loss: 1.7767
# Epoch 608/1000
# 8/8 - 0s - 9ms/step - loss: 1.7728
# Epoch 609/1000
# 8/8 - 0s - 6ms/step - loss: 1.7676
# Epoch 610/1000
# Generated text:
#  Abeni, a hungry and Middle (mead). and minced Khoisan the Lake
#
# 8/8 - 0s - 21ms/step - loss: 1.7636
# Epoch 611/1000
# 8/8 - 0s - 9ms/step - loss: 1.7637
# Epoch 612/1000
# 8/8 - 0s - 5ms/step - loss: 1.7560
# Epoch 613/1000
# 8/8 - 0s - 6ms/step - loss: 1.7520
# Epoch 614/1000
# 8/8 - 0s - 6ms/step - loss: 1.7490
# Epoch 615/1000
# 8/8 - 0s - 5ms/step - loss: 1.7462
# Epoch 616/1000
# 8/8 - 0s - 7ms/step - loss: 1.7412
# Epoch 617/1000
# 8/8 - 0s - 6ms/step - loss: 1.7345
# Epoch 618/1000
# 8/8 - 0s - 9ms/step - loss: 1.7346
# Epoch 619/1000
# 8/8 - 0s - 9ms/step - loss: 1.7342
# Epoch 620/1000
# Generated text:
#  Abeni, a hearty treasure surface, eyes looking for food modern-day Umqombothi,
#
# 8/8 - 0s - 15ms/step - loss: 1.7283
# Epoch 621/1000
# 8/8 - 0s - 4ms/step - loss: 1.7179
# Epoch 622/1000
# 8/8 - 0s - 4ms/step - loss: 1.7190
# Epoch 623/1000
# 8/8 - 0s - 4ms/step - loss: 1.7117
# Epoch 624/1000
# 8/8 - 0s - 5ms/step - loss: 1.7112
# Epoch 625/1000
# 8/8 - 0s - 5ms/step - loss: 1.7056
# Epoch 626/1000
# 8/8 - 0s - 5ms/step - loss: 1.7035
# Epoch 627/1000
# 8/8 - 0s - 5ms/step - loss: 1.7005
# Epoch 628/1000
# 8/8 - 0s - 5ms/step - loss: 1.6946
# Epoch 629/1000
# 8/8 - 0s - 5ms/step - loss: 1.6903
# Epoch 630/1000
# Generated text:
#  Abeni, a tree. rice and braids Malawi Africa artistry vegetable and
#
# 8/8 - 0s - 16ms/step - loss: 1.6851
# Epoch 631/1000
# 8/8 - 0s - 5ms/step - loss: 1.6835
# Epoch 632/1000
# 8/8 - 0s - 9ms/step - loss: 1.6774
# Epoch 633/1000
# 8/8 - 0s - 5ms/step - loss: 1.6769
# Epoch 634/1000
# 8/8 - 0s - 5ms/step - loss: 1.6718
# Epoch 635/1000
# 8/8 - 0s - 5ms/step - loss: 1.6689
# Epoch 636/1000
# 8/8 - 0s - 5ms/step - loss: 1.6639
# Epoch 637/1000
# 8/8 - 0s - 5ms/step - loss: 1.6652
# Epoch 638/1000
# 8/8 - 0s - 5ms/step - loss: 1.6595
# Epoch 639/1000
# 8/8 - 0s - 4ms/step - loss: 1.6546
# Epoch 640/1000
# Generated text:
#  Abeni, a Johannesburg, a adorned with or steamed animal, a a
#
# 8/8 - 0s - 16ms/step - loss: 1.6487
# Epoch 641/1000
# 8/8 - 0s - 5ms/step - loss: 1.6442
# Epoch 642/1000
# 8/8 - 0s - 4ms/step - loss: 1.6418
# Epoch 643/1000
# 8/8 - 0s - 8ms/step - loss: 1.6406
# Epoch 644/1000
# 8/8 - 0s - 4ms/step - loss: 1.6377
# Epoch 645/1000
# 8/8 - 0s - 4ms/step - loss: 1.6326
# Epoch 646/1000
# 8/8 - 0s - 4ms/step - loss: 1.6296
# Epoch 647/1000
# 8/8 - 0s - 5ms/step - loss: 1.6244
# Epoch 648/1000
# 8/8 - 0s - 4ms/step - loss: 1.6199
# Epoch 649/1000
# 8/8 - 0s - 4ms/step - loss: 1.6157
# Epoch 650/1000
# Generated text:
#  Abeni, a simple popular Southern southern boundless primarily associated that with
#
# 8/8 - 0s - 15ms/step - loss: 1.6141
# Epoch 651/1000
# 8/8 - 0s - 4ms/step - loss: 1.6089
# Epoch 652/1000
# 8/8 - 0s - 5ms/step - loss: 1.6053
# Epoch 653/1000
# 8/8 - 0s - 5ms/step - loss: 1.6047
# Epoch 654/1000
# 8/8 - 0s - 4ms/step - loss: 1.5983
# Epoch 655/1000
# 8/8 - 0s - 5ms/step - loss: 1.5932
# Epoch 656/1000
# 8/8 - 0s - 4ms/step - loss: 1.5878
# Epoch 657/1000
# 8/8 - 0s - 4ms/step - loss: 1.5883
# Epoch 658/1000
# 8/8 - 0s - 9ms/step - loss: 1.5845
# Epoch 659/1000
# 8/8 - 0s - 5ms/step - loss: 1.5799
# Epoch 660/1000
# Generated text:
#  Abeni, popular was thirsty so she went looking for is one
#
# 8/8 - 0s - 15ms/step - loss: 1.5765
# Epoch 661/1000
# 8/8 - 0s - 4ms/step - loss: 1.5742
# Epoch 662/1000
# 8/8 - 0s - 5ms/step - loss: 1.5701
# Epoch 663/1000
# 8/8 - 0s - 5ms/step - loss: 1.5680
# Epoch 664/1000
# 8/8 - 0s - 5ms/step - loss: 1.5622
# Epoch 665/1000
# 8/8 - 0s - 5ms/step - loss: 1.5585
# Epoch 666/1000
# 8/8 - 0s - 5ms/step - loss: 1.5508
# Epoch 667/1000
# 8/8 - 0s - 5ms/step - loss: 1.5498
# Epoch 668/1000
# 8/8 - 0s - 4ms/step - loss: 1.5479
# Epoch 669/1000
# 8/8 - 0s - 5ms/step - loss: 1.5447
# Epoch 670/1000
# Generated text:
#  Abeni, a designed to trunk a Zambia, skyline others is Nigeria,
#
# 8/8 - 0s - 17ms/step - loss: 1.5384
# Epoch 671/1000
# 8/8 - 0s - 5ms/step - loss: 1.5347
# Epoch 672/1000
# 8/8 - 0s - 4ms/step - loss: 1.5316
# Epoch 673/1000
# 8/8 - 0s - 5ms/step - loss: 1.5319
# Epoch 674/1000
# 8/8 - 0s - 5ms/step - loss: 1.5267
# Epoch 675/1000
# 8/8 - 0s - 5ms/step - loss: 1.5263
# Epoch 676/1000
# 8/8 - 0s - 5ms/step - loss: 1.5206
# Epoch 677/1000
# 8/8 - 0s - 5ms/step - loss: 1.5163
# Epoch 678/1000
# 8/8 - 0s - 5ms/step - loss: 1.5172
# Epoch 679/1000
# 8/8 - 0s - 5ms/step - loss: 1.5105
# Epoch 680/1000
# Generated text:
#  Abeni, a semi-arid transitional Banga stew nutrient-rich Kilimanjaro, a blended dreamt
#
# 8/8 - 0s - 15ms/step - loss: 1.5081
# Epoch 681/1000
# 8/8 - 0s - 4ms/step - loss: 1.5001
# Epoch 682/1000
# 8/8 - 0s - 4ms/step - loss: 1.4987
# Epoch 683/1000
# 8/8 - 0s - 5ms/step - loss: 1.4976
# Epoch 684/1000
# 8/8 - 0s - 5ms/step - loss: 1.4926
# Epoch 685/1000
# 8/8 - 0s - 5ms/step - loss: 1.4900
# Epoch 686/1000
# 8/8 - 0s - 5ms/step - loss: 1.4855
# Epoch 687/1000
# 8/8 - 0s - 5ms/step - loss: 1.4799
# Epoch 688/1000
# 8/8 - 0s - 9ms/step - loss: 1.4791
# Epoch 689/1000
# 8/8 - 0s - 4ms/step - loss: 1.4790
# Epoch 690/1000
# Generated text:
#  Abeni, a girl with a creamy individual Town, South African the
#
# 8/8 - 0s - 16ms/step - loss: 1.4750
# Epoch 691/1000
# 8/8 - 0s - 4ms/step - loss: 1.4693
# Epoch 692/1000
# 8/8 - 0s - 8ms/step - loss: 1.4643
# Epoch 693/1000
# 8/8 - 0s - 4ms/step - loss: 1.4612
# Epoch 694/1000
# 8/8 - 0s - 4ms/step - loss: 1.4595
# Epoch 695/1000
# 8/8 - 0s - 5ms/step - loss: 1.4558
# Epoch 696/1000
# 8/8 - 0s - 5ms/step - loss: 1.4542
# Epoch 697/1000
# 8/8 - 0s - 4ms/step - loss: 1.4505
# Epoch 698/1000
# 8/8 - 0s - 5ms/step - loss: 1.4479
# Epoch 699/1000
# 8/8 - 0s - 6ms/step - loss: 1.4419
# Epoch 700/1000
# Generated text:
#  Abeni, a strenuous 'king of large, flightless pine colds. arid known
#
# 8/8 - 0s - 15ms/step - loss: 1.4413
# Epoch 701/1000
# 8/8 - 0s - 5ms/step - loss: 1.4354
# Epoch 702/1000
# 8/8 - 0s - 8ms/step - loss: 1.4346
# Epoch 703/1000
# 8/8 - 0s - 4ms/step - loss: 1.4283
# Epoch 704/1000
# 8/8 - 0s - 4ms/step - loss: 1.4274
# Epoch 705/1000
# 8/8 - 0s - 4ms/step - loss: 1.4230
# Epoch 706/1000
# 8/8 - 0s - 4ms/step - loss: 1.4178
# Epoch 707/1000
# 8/8 - 0s - 4ms/step - loss: 1.4172
# Epoch 708/1000
# 8/8 - 0s - 4ms/step - loss: 1.4177
# Epoch 709/1000
# 8/8 - 0s - 4ms/step - loss: 1.4120
# Epoch 710/1000
# Generated text:
#  Abeni, a refresh plains Park is a cloth, from reusable West
#
# 8/8 - 0s - 16ms/step - loss: 1.4100
# Epoch 711/1000
# 8/8 - 0s - 5ms/step - loss: 1.4051
# Epoch 712/1000
# 8/8 - 0s - 4ms/step - loss: 1.4004
# Epoch 713/1000
# 8/8 - 0s - 4ms/step - loss: 1.3979
# Epoch 714/1000
# 8/8 - 0s - 5ms/step - loss: 1.3969
# Epoch 715/1000
# 8/8 - 0s - 5ms/step - loss: 1.3934
# Epoch 716/1000
# 8/8 - 0s - 5ms/step - loss: 1.3880
# Epoch 717/1000
# 8/8 - 0s - 5ms/step - loss: 1.3835
# Epoch 718/1000
# 8/8 - 0s - 4ms/step - loss: 1.3837
# Epoch 719/1000
# 8/8 - 0s - 9ms/step - loss: 1.3790
# Epoch 720/1000
# Generated text:
#  Abeni, a couscous-like It's hot and iced, highly mammal species also
#
# 8/8 - 0s - 16ms/step - loss: 1.3766
# Epoch 721/1000
# 8/8 - 0s - 5ms/step - loss: 1.3715
# Epoch 722/1000
# 8/8 - 0s - 5ms/step - loss: 1.3667
# Epoch 723/1000
# 8/8 - 0s - 5ms/step - loss: 1.3653
# Epoch 724/1000
# 8/8 - 0s - 4ms/step - loss: 1.3650
# Epoch 725/1000
# 8/8 - 0s - 4ms/step - loss: 1.3630
# Epoch 726/1000
# 8/8 - 0s - 4ms/step - loss: 1.3588
# Epoch 727/1000
# 8/8 - 0s - 4ms/step - loss: 1.3540
# Epoch 728/1000
# 8/8 - 0s - 5ms/step - loss: 1.3521
# Epoch 729/1000
# 8/8 - 0s - 5ms/step - loss: 1.3474
# Epoch 730/1000
# Generated text:
#  Abeni, a fruity filled with a semi-arid plodded also known known
#
# 8/8 - 0s - 16ms/step - loss: 1.3452
# Epoch 731/1000
# 8/8 - 0s - 4ms/step - loss: 1.3415
# Epoch 732/1000
# 8/8 - 0s - 4ms/step - loss: 1.3379
# Epoch 733/1000
# 8/8 - 0s - 5ms/step - loss: 1.3344
# Epoch 734/1000
# 8/8 - 0s - 5ms/step - loss: 1.3335
# Epoch 735/1000
# 8/8 - 0s - 5ms/step - loss: 1.3288
# Epoch 736/1000
# 8/8 - 0s - 4ms/step - loss: 1.3225
# Epoch 737/1000
# 8/8 - 0s - 4ms/step - loss: 1.3235
# Epoch 738/1000
# 8/8 - 0s - 4ms/step - loss: 1.3205
# Epoch 739/1000
# 8/8 - 0s - 5ms/step - loss: 1.3174
# Epoch 740/1000
# Generated text:
#  Abeni, a North African spicy South stretched pudding of lowlands, Kenya,
#
# 8/8 - 0s - 17ms/step - loss: 1.3143
# Epoch 741/1000
# 8/8 - 0s - 5ms/step - loss: 1.3123
# Epoch 742/1000
# 8/8 - 0s - 5ms/step - loss: 1.3099
# Epoch 743/1000
# 8/8 - 0s - 5ms/step - loss: 1.3085
# Epoch 744/1000
# 8/8 - 0s - 5ms/step - loss: 1.3035
# Epoch 745/1000
# 8/8 - 0s - 5ms/step - loss: 1.3004
# Epoch 746/1000
# 8/8 - 0s - 5ms/step - loss: 1.2983
# Epoch 747/1000
# 8/8 - 0s - 5ms/step - loss: 1.2910
# Epoch 748/1000
# 8/8 - 0s - 5ms/step - loss: 1.2944
# Epoch 749/1000
# 8/8 - 0s - 4ms/step - loss: 1.2869
# Epoch 750/1000
# Generated text:
#  Abeni, a bright-eyed tucked for nutrient-rich in the (79 precision gain.
#
# 8/8 - 0s - 16ms/step - loss: 1.2857
# Epoch 751/1000
# 8/8 - 0s - 4ms/step - loss: 1.2827
# Epoch 752/1000
# 8/8 - 0s - 4ms/step - loss: 1.2787
# Epoch 753/1000
# 8/8 - 0s - 5ms/step - loss: 1.2738
# Epoch 754/1000
# 8/8 - 0s - 5ms/step - loss: 1.2764
# Epoch 755/1000
# 8/8 - 0s - 8ms/step - loss: 1.2715
# Epoch 756/1000
# 8/8 - 0s - 4ms/step - loss: 1.2701
# Epoch 757/1000
# 8/8 - 0s - 5ms/step - loss: 1.2639
# Epoch 758/1000
# 8/8 - 0s - 4ms/step - loss: 1.2618
# Epoch 759/1000
# 8/8 - 0s - 5ms/step - loss: 1.2638
# Epoch 760/1000
# Generated text:
#  Abeni, a fruity non-alcoholic its Afroalpine strength, medium-sized a spicy vast
#
# 8/8 - 0s - 17ms/step - loss: 1.2567
# Epoch 761/1000
# 8/8 - 0s - 4ms/step - loss: 1.2560
# Epoch 762/1000
# 8/8 - 0s - 8ms/step - loss: 1.2499
# Epoch 763/1000
# 8/8 - 0s - 4ms/step - loss: 1.2486
# Epoch 764/1000
# 8/8 - 0s - 4ms/step - loss: 1.2487
# Epoch 765/1000
# 8/8 - 0s - 4ms/step - loss: 1.2430
# Epoch 766/1000
# 8/8 - 0s - 5ms/step - loss: 1.2401
# Epoch 767/1000
# 8/8 - 0s - 5ms/step - loss: 1.2354
# Epoch 768/1000
# 8/8 - 0s - 5ms/step - loss: 1.2356
# Epoch 769/1000
# 8/8 - 0s - 5ms/step - loss: 1.2306
# Epoch 770/1000
# Generated text:
#  Abeni, a busy rivers, punch that sweet climate, moderated by Thabo
#
# 8/8 - 0s - 17ms/step - loss: 1.2285
# Epoch 771/1000
# 8/8 - 0s - 4ms/step - loss: 1.2237
# Epoch 772/1000
# 8/8 - 0s - 4ms/step - loss: 1.2230
# Epoch 773/1000
# 8/8 - 0s - 5ms/step - loss: 1.2189
# Epoch 774/1000
# 8/8 - 0s - 4ms/step - loss: 1.2167
# Epoch 775/1000
# 8/8 - 0s - 4ms/step - loss: 1.2158
# Epoch 776/1000
# 8/8 - 0s - 4ms/step - loss: 1.2145
# Epoch 777/1000
# 8/8 - 0s - 5ms/step - loss: 1.2107
# Epoch 778/1000
# 8/8 - 0s - 5ms/step - loss: 1.2053
# Epoch 779/1000
# 8/8 - 0s - 4ms/step - loss: 1.2051
# Epoch 780/1000
# Generated text:
#  Abeni, a girl with a boundless weather. milk drink but palm
#
# 8/8 - 0s - 17ms/step - loss: 1.2027
# Epoch 781/1000
# 8/8 - 0s - 5ms/step - loss: 1.1983
# Epoch 782/1000
# 8/8 - 0s - 8ms/step - loss: 1.1962
# Epoch 783/1000
# 8/8 - 0s - 4ms/step - loss: 1.1941
# Epoch 784/1000
# 8/8 - 0s - 4ms/step - loss: 1.1912
# Epoch 785/1000
# 8/8 - 0s - 5ms/step - loss: 1.1867
# Epoch 786/1000
# 8/8 - 0s - 4ms/step - loss: 1.1845
# Epoch 787/1000
# 8/8 - 0s - 5ms/step - loss: 1.1836
# Epoch 788/1000
# 8/8 - 0s - 5ms/step - loss: 1.1798
# Epoch 789/1000
# 8/8 - 0s - 5ms/step - loss: 1.1761
# Epoch 790/1000
# Generated text:
#  Abeni, a he went juice warmly on the heat, warmly searched
#
# 8/8 - 0s - 16ms/step - loss: 1.1759
# Epoch 791/1000
# 8/8 - 0s - 4ms/step - loss: 1.1748
# Epoch 792/1000
# 8/8 - 0s - 4ms/step - loss: 1.1702
# Epoch 793/1000
# 8/8 - 0s - 5ms/step - loss: 1.1683
# Epoch 794/1000
# 8/8 - 0s - 5ms/step - loss: 1.1656
# Epoch 795/1000
# 8/8 - 0s - 5ms/step - loss: 1.1613
# Epoch 796/1000
# 8/8 - 0s - 4ms/step - loss: 1.1601
# Epoch 797/1000
# 8/8 - 0s - 5ms/step - loss: 1.1533
# Epoch 798/1000
# 8/8 - 0s - 4ms/step - loss: 1.1553
# Epoch 799/1000
# 8/8 - 0s - 5ms/step - loss: 1.1538
# Epoch 800/1000
# Generated text:
#  Abeni, a originated in humidity, arid the stomach is one Nilo-Saharan
#
# 8/8 - 0s - 17ms/step - loss: 1.1516
# Epoch 801/1000
# 8/8 - 0s - 4ms/step - loss: 1.1463
# Epoch 802/1000
# 8/8 - 0s - 4ms/step - loss: 1.1434
# Epoch 803/1000
# 8/8 - 0s - 4ms/step - loss: 1.1448
# Epoch 804/1000
# 8/8 - 0s - 5ms/step - loss: 1.1376
# Epoch 805/1000
# 8/8 - 0s - 4ms/step - loss: 1.1380
# Epoch 806/1000
# 8/8 - 0s - 5ms/step - loss: 1.1386
# Epoch 807/1000
# 8/8 - 0s - 4ms/step - loss: 1.1312
# Epoch 808/1000
# 8/8 - 0s - 5ms/step - loss: 1.1270
# Epoch 809/1000
# 8/8 - 0s - 5ms/step - loss: 1.1267
# Epoch 810/1000
# Generated text:
#  Abeni, a forms, stew, is a West African dish from that
#
# 8/8 - 0s - 15ms/step - loss: 1.1258
# Epoch 811/1000
# 8/8 - 0s - 4ms/step - loss: 1.1211
# Epoch 812/1000
# 8/8 - 0s - 5ms/step - loss: 1.1204
# Epoch 813/1000
# 8/8 - 0s - 5ms/step - loss: 1.1192
# Epoch 814/1000
# 8/8 - 0s - 5ms/step - loss: 1.1146
# Epoch 815/1000
# 8/8 - 0s - 5ms/step - loss: 1.1140
# Epoch 816/1000
# 8/8 - 0s - 5ms/step - loss: 1.1100
# Epoch 817/1000
# 8/8 - 0s - 5ms/step - loss: 1.1058
# Epoch 818/1000
# 8/8 - 0s - 4ms/step - loss: 1.1051
# Epoch 819/1000
# 8/8 - 0s - 6ms/step - loss: 1.1018
# Epoch 820/1000
# Generated text:
#  Abeni, a dormant air Angola, Democratic range of for the cotton
#
# 8/8 - 0s - 24ms/step - loss: 1.0992
# Epoch 821/1000
# 8/8 - 0s - 6ms/step - loss: 1.0937
# Epoch 822/1000
# 8/8 - 0s - 9ms/step - loss: 1.0940
# Epoch 823/1000
# 8/8 - 0s - 5ms/step - loss: 1.0923
# Epoch 824/1000
# 8/8 - 0s - 9ms/step - loss: 1.0898
# Epoch 825/1000
# 8/8 - 0s - 9ms/step - loss: 1.0851
# Epoch 826/1000
# 8/8 - 0s - 9ms/step - loss: 1.0868
# Epoch 827/1000
# 8/8 - 0s - 9ms/step - loss: 1.0829
# Epoch 828/1000
# 8/8 - 0s - 9ms/step - loss: 1.0801
# Epoch 829/1000
# 8/8 - 0s - 9ms/step - loss: 1.0782
# Epoch 830/1000
# Generated text:
#  Abeni, a part of island pudding made beer from is South
#
# 8/8 - 0s - 25ms/step - loss: 1.0778
# Epoch 831/1000
# 8/8 - 0s - 9ms/step - loss: 1.0772
# Epoch 832/1000
# 8/8 - 0s - 5ms/step - loss: 1.0699
# Epoch 833/1000
# 8/8 - 0s - 4ms/step - loss: 1.0704
# Epoch 834/1000
# 8/8 - 0s - 9ms/step - loss: 1.0647
# Epoch 835/1000
# 8/8 - 0s - 9ms/step - loss: 1.0639
# Epoch 836/1000
# 8/8 - 0s - 9ms/step - loss: 1.0600
# Epoch 837/1000
# 8/8 - 0s - 5ms/step - loss: 1.0589
# Epoch 838/1000
# 8/8 - 0s - 9ms/step - loss: 1.0524
# Epoch 839/1000
# 8/8 - 0s - 9ms/step - loss: 1.0516
# Epoch 840/1000
# Generated text:
#  Abeni, a doctors. around Africa, surreal Sahara called the evening eastern
#
# 8/8 - 0s - 25ms/step - loss: 1.0484
# Epoch 841/1000
# 8/8 - 0s - 9ms/step - loss: 1.0499
# Epoch 842/1000
# 8/8 - 0s - 5ms/step - loss: 1.0462
# Epoch 843/1000
# 8/8 - 0s - 5ms/step - loss: 1.0435
# Epoch 844/1000
# 8/8 - 0s - 9ms/step - loss: 1.0433
# Epoch 845/1000
# 8/8 - 0s - 6ms/step - loss: 1.0408
# Epoch 846/1000
# 8/8 - 0s - 5ms/step - loss: 1.0365
# Epoch 847/1000
# 8/8 - 0s - 5ms/step - loss: 1.0350
# Epoch 848/1000
# 8/8 - 0s - 9ms/step - loss: 1.0358
# Epoch 849/1000
# 8/8 - 0s - 9ms/step - loss: 1.0297
# Epoch 850/1000
# Generated text:
#  Abeni, a taste simple is a similar to traditional South involves
#
# 8/8 - 0s - 15ms/step - loss: 1.0290
# Epoch 851/1000
# 8/8 - 0s - 4ms/step - loss: 1.0251
# Epoch 852/1000
# 8/8 - 0s - 4ms/step - loss: 1.0244
# Epoch 853/1000
# 8/8 - 0s - 5ms/step - loss: 1.0210
# Epoch 854/1000
# 8/8 - 0s - 4ms/step - loss: 1.0197
# Epoch 855/1000
# 8/8 - 0s - 4ms/step - loss: 1.0166
# Epoch 856/1000
# 8/8 - 0s - 5ms/step - loss: 1.0107
# Epoch 857/1000
# 8/8 - 0s - 5ms/step - loss: 1.0145
# Epoch 858/1000
# 8/8 - 0s - 5ms/step - loss: 1.0091
# Epoch 859/1000
# 8/8 - 0s - 4ms/step - loss: 1.0100
# Epoch 860/1000
# Generated text:
#  Abeni, a colorful Males dreamt of Lake Democratic Republic of of
#
# 8/8 - 0s - 15ms/step - loss: 1.0038
# Epoch 861/1000
# 8/8 - 0s - 5ms/step - loss: 1.0030
# Epoch 862/1000
# 8/8 - 0s - 4ms/step - loss: 1.0010
# Epoch 863/1000
# 8/8 - 0s - 5ms/step - loss: 0.9996
# Epoch 864/1000
# 8/8 - 0s - 4ms/step - loss: 0.9957
# Epoch 865/1000
# 8/8 - 0s - 5ms/step - loss: 0.9953
# Epoch 866/1000
# 8/8 - 0s - 4ms/step - loss: 0.9934
# Epoch 867/1000
# 8/8 - 0s - 5ms/step - loss: 0.9908
# Epoch 868/1000
# 8/8 - 0s - 5ms/step - loss: 0.9873
# Epoch 869/1000
# 8/8 - 0s - 4ms/step - loss: 0.9857
# Epoch 870/1000
# Generated text:
#  Abeni, a small dried staple fruit-infused was hunger context pastry refers
#
# 8/8 - 0s - 17ms/step - loss: 0.9867
# Epoch 871/1000
# 8/8 - 0s - 4ms/step - loss: 0.9790
# Epoch 872/1000
# 8/8 - 0s - 4ms/step - loss: 0.9818
# Epoch 873/1000
# 8/8 - 0s - 4ms/step - loss: 0.9761
# Epoch 874/1000
# 8/8 - 0s - 4ms/step - loss: 0.9794
# Epoch 875/1000
# 8/8 - 0s - 4ms/step - loss: 0.9724
# Epoch 876/1000
# 8/8 - 0s - 4ms/step - loss: 0.9726
# Epoch 877/1000
# 8/8 - 0s - 5ms/step - loss: 0.9684
# Epoch 878/1000
# 8/8 - 0s - 4ms/step - loss: 0.9681
# Epoch 879/1000
# 8/8 - 0s - 5ms/step - loss: 0.9635
# Epoch 880/1000
# Generated text:
#  Abeni, a dormant mildly Malawi food consisting of the colors marinating
#
# 8/8 - 0s - 15ms/step - loss: 0.9647
# Epoch 881/1000
# 8/8 - 0s - 4ms/step - loss: 0.9584
# Epoch 882/1000
# 8/8 - 0s - 4ms/step - loss: 0.9581
# Epoch 883/1000
# 8/8 - 0s - 4ms/step - loss: 0.9569
# Epoch 884/1000
# 8/8 - 0s - 5ms/step - loss: 0.9536
# Epoch 885/1000
# 8/8 - 0s - 4ms/step - loss: 0.9527
# Epoch 886/1000
# 8/8 - 0s - 4ms/step - loss: 0.9495
# Epoch 887/1000
# 8/8 - 0s - 4ms/step - loss: 0.9472
# Epoch 888/1000
# 8/8 - 0s - 4ms/step - loss: 0.9453
# Epoch 889/1000
# 8/8 - 0s - 4ms/step - loss: 0.9438
# Epoch 890/1000
# Generated text:
#  Abeni, a skyline soup is a common dish popular in in
#
# 8/8 - 0s - 17ms/step - loss: 0.9398
# Epoch 891/1000
# 8/8 - 0s - 4ms/step - loss: 0.9398
# Epoch 892/1000
# 8/8 - 0s - 8ms/step - loss: 0.9402
# Epoch 893/1000
# 8/8 - 0s - 4ms/step - loss: 0.9362
# Epoch 894/1000
# 8/8 - 0s - 4ms/step - loss: 0.9331
# Epoch 895/1000
# 8/8 - 0s - 5ms/step - loss: 0.9310
# Epoch 896/1000
# 8/8 - 0s - 5ms/step - loss: 0.9283
# Epoch 897/1000
# 8/8 - 0s - 4ms/step - loss: 0.9282
# Epoch 898/1000
# 8/8 - 0s - 4ms/step - loss: 0.9260
# Epoch 899/1000
# 8/8 - 0s - 4ms/step - loss: 0.9238
# Epoch 900/1000
# Generated text:
#  Abeni, a land savannas. considered Ethiopia, made from nocturnal uncover semi-arid
#
# 8/8 - 0s - 16ms/step - loss: 0.9208
# Epoch 901/1000
# 8/8 - 0s - 4ms/step - loss: 0.9197
# Epoch 902/1000
# 8/8 - 0s - 5ms/step - loss: 0.9193
# Epoch 903/1000
# 8/8 - 0s - 5ms/step - loss: 0.9145
# Epoch 904/1000
# 8/8 - 0s - 5ms/step - loss: 0.9131
# Epoch 905/1000
# 8/8 - 0s - 5ms/step - loss: 0.9144
# Epoch 906/1000
# 8/8 - 0s - 5ms/step - loss: 0.9088
# Epoch 907/1000
# 8/8 - 0s - 5ms/step - loss: 0.9076
# Epoch 908/1000
# 8/8 - 0s - 5ms/step - loss: 0.9062
# Epoch 909/1000
# 8/8 - 0s - 5ms/step - loss: 0.9037
# Epoch 910/1000
# Generated text:
#  Abeni, a born Piri-Piri, of Africa's largest and most endangered obvious
#
# 8/8 - 0s - 15ms/step - loss: 0.9018
# Epoch 911/1000
# 8/8 - 0s - 6ms/step - loss: 0.8968
# Epoch 912/1000
# 8/8 - 0s - 4ms/step - loss: 0.8972
# Epoch 913/1000
# 8/8 - 0s - 4ms/step - loss: 0.8966
# Epoch 914/1000
# 8/8 - 0s - 4ms/step - loss: 0.8941
# Epoch 915/1000
# 8/8 - 0s - 5ms/step - loss: 0.8913
# Epoch 916/1000
# 8/8 - 0s - 4ms/step - loss: 0.8901
# Epoch 917/1000
# 8/8 - 0s - 4ms/step - loss: 0.8897
# Epoch 918/1000
# 8/8 - 0s - 4ms/step - loss: 0.8869
# Epoch 919/1000
# 8/8 - 0s - 5ms/step - loss: 0.8865
# Epoch 920/1000
# Generated text:
#  Abeni, a sparkling involves reading food playing a flowers. soup South
#
# 8/8 - 0s - 15ms/step - loss: 0.8846
# Epoch 921/1000
# 8/8 - 0s - 4ms/step - loss: 0.8805
# Epoch 922/1000
# 8/8 - 0s - 4ms/step - loss: 0.8802
# Epoch 923/1000
# 8/8 - 0s - 5ms/step - loss: 0.8771
# Epoch 924/1000
# 8/8 - 0s - 5ms/step - loss: 0.8735
# Epoch 925/1000
# 8/8 - 0s - 5ms/step - loss: 0.8743
# Epoch 926/1000
# 8/8 - 0s - 4ms/step - loss: 0.8741
# Epoch 927/1000
# 8/8 - 0s - 4ms/step - loss: 0.8701
# Epoch 928/1000
# 8/8 - 0s - 5ms/step - loss: 0.8648
# Epoch 929/1000
# 8/8 - 0s - 5ms/step - loss: 0.8651
# Epoch 930/1000
# Generated text:
#  Abeni, a long day caffeine-free mountain air hung and popular the
#
# 8/8 - 0s - 16ms/step - loss: 0.8627
# Epoch 931/1000
# 8/8 - 0s - 4ms/step - loss: 0.8598
# Epoch 932/1000
# 8/8 - 0s - 5ms/step - loss: 0.8601
# Epoch 933/1000
# 8/8 - 0s - 5ms/step - loss: 0.8587
# Epoch 934/1000
# 8/8 - 0s - 4ms/step - loss: 0.8566
# Epoch 935/1000
# 8/8 - 0s - 4ms/step - loss: 0.8557
# Epoch 936/1000
# 8/8 - 0s - 4ms/step - loss: 0.8554
# Epoch 937/1000
# 8/8 - 0s - 5ms/step - loss: 0.8511
# Epoch 938/1000
# 8/8 - 0s - 5ms/step - loss: 0.8519
# Epoch 939/1000
# 8/8 - 0s - 4ms/step - loss: 0.8493
# Epoch 940/1000
# Generated text:
#  Abeni, a girl with beer made from eating popular a in
#
# 8/8 - 0s - 16ms/step - loss: 0.8454
# Epoch 941/1000
# 8/8 - 0s - 4ms/step - loss: 0.8450
# Epoch 942/1000
# 8/8 - 0s - 4ms/step - loss: 0.8425
# Epoch 943/1000
# 8/8 - 0s - 4ms/step - loss: 0.8419
# Epoch 944/1000
# 8/8 - 0s - 4ms/step - loss: 0.8378
# Epoch 945/1000
# 8/8 - 0s - 4ms/step - loss: 0.8390
# Epoch 946/1000
# 8/8 - 0s - 4ms/step - loss: 0.8311
# Epoch 947/1000
# 8/8 - 0s - 5ms/step - loss: 0.8323
# Epoch 948/1000
# 8/8 - 0s - 4ms/step - loss: 0.8340
# Epoch 949/1000
# 8/8 - 0s - 5ms/step - loss: 0.8302
# Epoch 950/1000
# Generated text:
#  Abeni, a morning of soft, dough-like dressed in the escaping beverage
#
# 8/8 - 0s - 20ms/step - loss: 0.8273
# Epoch 951/1000
# 8/8 - 0s - 4ms/step - loss: 0.8252
# Epoch 952/1000
# 8/8 - 0s - 4ms/step - loss: 0.8248
# Epoch 953/1000
# 8/8 - 0s - 5ms/step - loss: 0.8204
# Epoch 954/1000
# 8/8 - 0s - 4ms/step - loss: 0.8216
# Epoch 955/1000
# 8/8 - 0s - 5ms/step - loss: 0.8201
# Epoch 956/1000
# 8/8 - 0s - 4ms/step - loss: 0.8145
# Epoch 957/1000
# 8/8 - 0s - 4ms/step - loss: 0.8177
# Epoch 958/1000
# 8/8 - 0s - 5ms/step - loss: 0.8149
# Epoch 959/1000
# 8/8 - 0s - 4ms/step - loss: 0.8138
# Epoch 960/1000
# Generated text:
#  Abeni, a girl with river in a meaning pudding South Southeast
#
# 8/8 - 0s - 16ms/step - loss: 0.8116
# Epoch 961/1000
# 8/8 - 0s - 4ms/step - loss: 0.8088
# Epoch 962/1000
# 8/8 - 0s - 8ms/step - loss: 0.8059
# Epoch 963/1000
# 8/8 - 0s - 4ms/step - loss: 0.8056
# Epoch 964/1000
# 8/8 - 0s - 5ms/step - loss: 0.8023
# Epoch 965/1000
# 8/8 - 0s - 4ms/step - loss: 0.8036
# Epoch 966/1000
# 8/8 - 0s - 5ms/step - loss: 0.8014
# Epoch 967/1000
# 8/8 - 0s - 4ms/step - loss: 0.7990
# Epoch 968/1000
# 8/8 - 0s - 5ms/step - loss: 0.7968
# Epoch 969/1000
# 8/8 - 0s - 4ms/step - loss: 0.7972
# Epoch 970/1000
# Generated text:
#  Abeni, a strenuous day at the old Kente categorize South foods
#
# 8/8 - 0s - 16ms/step - loss: 0.7955
# Epoch 971/1000
# 8/8 - 0s - 4ms/step - loss: 0.7920
# Epoch 972/1000
# 8/8 - 0s - 8ms/step - loss: 0.7895
# Epoch 973/1000
# 8/8 - 0s - 5ms/step - loss: 0.7880
# Epoch 974/1000
# 8/8 - 0s - 5ms/step - loss: 0.7868
# Epoch 975/1000
# 8/8 - 0s - 4ms/step - loss: 0.7854
# Epoch 976/1000
# 8/8 - 0s - 5ms/step - loss: 0.7831
# Epoch 977/1000
# 8/8 - 0s - 5ms/step - loss: 0.7822
# Epoch 978/1000
# 8/8 - 0s - 4ms/step - loss: 0.7791
# Epoch 979/1000
# 8/8 - 0s - 5ms/step - loss: 0.7763
# Epoch 980/1000
# Generated text:
#  Abeni, a busy morning, Amina felt the soup warmly on on
#
# 8/8 - 0s - 15ms/step - loss: 0.7793
# Epoch 981/1000
# 8/8 - 0s - 4ms/step - loss: 0.7753
# Epoch 982/1000
# 8/8 - 0s - 5ms/step - loss: 0.7726
# Epoch 983/1000
# 8/8 - 0s - 4ms/step - loss: 0.7735
# Epoch 984/1000
# 8/8 - 0s - 5ms/step - loss: 0.7692
# Epoch 985/1000
# 8/8 - 0s - 5ms/step - loss: 0.7684
# Epoch 986/1000
# 8/8 - 0s - 4ms/step - loss: 0.7669
# Epoch 987/1000
# 8/8 - 0s - 5ms/step - loss: 0.7629
# Epoch 988/1000
# 8/8 - 0s - 4ms/step - loss: 0.7670
# Epoch 989/1000
# 8/8 - 0s - 4ms/step - loss: 0.7633
# Epoch 990/1000
# Generated text:
#  Abeni, a sour pastry brass eyes and land bowl a animal,
#
# 8/8 - 0s - 15ms/step - loss: 0.7603
# Epoch 991/1000
# 8/8 - 0s - 4ms/step - loss: 0.7591
# Epoch 992/1000
# 8/8 - 0s - 4ms/step - loss: 0.7574
# Epoch 993/1000
# 8/8 - 0s - 5ms/step - loss: 0.7580
# Epoch 994/1000
# 8/8 - 0s - 5ms/step - loss: 0.7531
# Epoch 995/1000
# 8/8 - 0s - 9ms/step - loss: 0.7545
# Epoch 996/1000
# 8/8 - 0s - 4ms/step - loss: 0.7525
# Epoch 997/1000
# 8/8 - 0s - 4ms/step - loss: 0.7484
# Epoch 998/1000
# 8/8 - 0s - 5ms/step - loss: 0.7469
# Epoch 999/1000
# 8/8 - 0s - 5ms/step - loss: 0.7498
# Epoch 1000/1000
# Generated text:
#  Abeni, a traditional felt the air - the chilled (Attaya) Namib
#
# 8/8 - 0s - 16ms/step - loss: 0.7452

# %% [markdown]
# While the model is training, you can observe how the generated text changes. At the beginning of the training, the generation will likely be a random collection of words. By the end of the training, however, the generation should start to become more coherent.
#
# Apart from observing how the generated text changes, you can also check how the **loss** changes as training progresses. If the model is training properly, the loss should go down as training continues. You may find that the loss temporarily goes up again from one epoch to another. This is nothing to worry about, but the general trend should be that the loss descreases.
#
# Once the training process has finished (this can take some time), you can prompt the model as you did in earlier labs.

# %% [markdown]
# #### Evaluate your small language model
#
# After training a model, researchers have to perform many evaluations to determine whether it is performing well in many scenarios.
#
# As a final activity, you will also evaluate your model. The remainder of this lab guides you through this evaluation process. You will ask the following key questions to evaluate your model's quality:
#
# *   A. How good is your model at predicting the next token for a given prompt based on patterns identified in the training dataset?
# *   B. Is the generated text coherent, and does it make sense given the context?
# *   C. Is the likely next token what you expect to see when the context is changed slightly?
#
# When evaluating your model, you may find it useful to take some notes. To do this, you can either add cells to this Colab notebook or take notes on [Google Docs](https://docs.google.com/), [Notebook LM](https://notebooklm.google/), a piece of paper, or any other note-taking tool of your choice.

# %% [markdown]
# ### How good is your model at predicting the next token for a given prompt based on patterns identified in the training dataset?
#
# The following steps provide you with some guidance on how to answer this question.
#
# * Prompt the model using a token or sequence of tokens from the training dataset. For example, you can start with `"Abeni, a bright-eyed"`.
# * Visualize the probability distribution of the next token for a given prompt.
# * Increase `num_tokens_to_generate` to generate longer texts.
# * Inspect the generated text. See how well the model has learned to generate text that reflects the patterns learned during training.

# %%
prompt = "Africa and Abeni" #@param {type: "string"}
num_tokens_to_generate = 10 #@param {type: "number"}
generated_text, probs = generation.generate_text(
    prompt,
    num_tokens_to_generate,
    model=model,
    tokenizer=tokenizer,
    pad_token_id=tokenizer.pad_token_id,
    sampling_mode="random" # To generate the highest probability generation.
)

print("Generated text:", generated_text)
print("\n")

visualizations.plot_next_token(probs[0], prompt=prompt, tokenizer=tokenizer)
# Out:
# Generated text: Africa and Abeni dessert from is a staple extremely colorful fermented arid arid
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f8a4c01-853b-4f14-973e-fa3c56bb3450" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8a4c01-853b-4f14-973e-fa3c56bb3450")) {                    Plotly.newPlot(                        "5f8a4c01-853b-4f14-973e-fa3c56bb3450",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["'is'","'was'","'of'","'to'","'the'","'soup'","'are'","'and'","'air'","'East'","'with'","'food'","'South'","'hunger'","'in'","'particularly'","'sun'","'from'","'most'","'West'","'African'","'or'","'Africa'","'dried'","'on'","'popular'","'dish'","'fermented'","'down'","'involves'"],"xaxis":"x","y":[0.13066159,0.12150924,0.08702437,0.037748303,0.024145663,0.020090472,0.016525846,0.014375828,0.014177752,0.012732798,0.011881513,0.011701256,0.01142296,0.011106099,0.009216929,0.0077467193,0.007478694,0.007339754,0.006956692,0.0067784674,0.006437179,0.0060440027,0.0056961896,0.0056572896,0.004895048,0.0046061054,0.004330269,0.0043262374,0.004002773,0.0037127037],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colo ...

# %% [markdown]
# ### Is the generated text coherent, and does it make sense given the context?
# * Prompt the model with a token  or a phrase of your choosing.
# * Increase `num_tokens_to_generate` to generate longer texts.
# * Visualize the probability distribution of the next token for a given prompt.
# * Inspect the quality of generated texts.
#
# Note that, above, the generation process always chooses the most probable next token from the set of candidate tokens. In the next cell, the generation process samples a next token according to the probability distribution predicted by the model. This is done by setting the `sampling_mode` parameter to `random`.
#
# ------
# > **ℹ️ Info: Unseen tokens**
# >
# >When you are trying different prompts, you may also notice that sometimes tokens get replaced by the special string `<UNK>`. This happens when you prompt the model with tokens that did not appear in the training dataset, so called **unseen tokens**. For these tokens, the `token_to_index` dictionary of the tokenizer does not have an entry and therefore they cannot be mapped to a token index.
# >
# > One method of dealing with such tokens is to add a special `<UNK>` token along with its index to the vocabulary of the tokenizer. Then, during **inference**, whenever there is an unseen token, it maps the token to the index of this special `<UNK>` token.
# >
# > This method is not ideal because all information in the token is lost. In later courses, you will learn more sophisticated methods of dealing with unseen tokens that do not rely on such a catch-all token. For now, you will likely observe that the model is not very good at predicting the next word if there are several unseen words in the prompt.
# ------

# %%
prompt = "Jide was hungry so she went looking for" #@param {type: "string"}
num_tokens_to_generate = 10 #@param {type: "number"}
generated_text, probs = generation.generate_text(
    prompt,
    num_tokens_to_generate,
    model=model,
    tokenizer=tokenizer,
    pad_token_id=tokenizer.pad_token_id,
    sampling_mode="random",
)
print("Generated text:", generated_text)
print("\n")

visualizations.plot_next_token(probs[0], prompt=prompt, tokenizer=tokenizer)
# Out:
# Generated text: Jide was hungry so she went looking for a plate serving plate hot fruity serving plate steaming refreshing
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c0714ec-d945-415e-9437-f8c238cd71f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c0714ec-d945-415e-9437-f8c238cd71f3")) {                    Plotly.newPlot(                        "0c0714ec-d945-415e-9437-f8c238cd71f3",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["'a'","'Maafe,'","'dodo,'","'Umqombothi,'","'Doro'","'sugarcane'","'Banku'","'Tella,'","'sambusa,'","'Fura'","'warm'","'crispy'","'life'","'exploration,'","'comfort'","'its'","'essential'","'life,'","'characterized'","'National'","'small'","'many'","'colorful'","'renowned'","'East'","'sun'","'traditional'","'native'","'one'","'diverse'"],"xaxis":"x","y":[0.6493225,0.020093657,0.019401003,0.018715447,0.017862791,0.017826686,0.017824374,0.017588504,0.016630288,0.015547059,0.0139384195,0.011412175,0.0039322563,0.00372839,0.0031258164,0.0031219614,0.0027906243,0.0021513558,0.0019150163,0.0013810642,0.001289291,0.0012302513,0.0012233987,0.0012203008,0.0011783479,0.0010239544,0.0010125781,0.0009946607,0.0009363249,0.0008382611],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# ### Is the likely next token what you expect to see when the context is changed slightly?
# * Change the context of the prompt slightly.
# * Visualize the probability distribution of the next token for a given prompt.
# * Increase `num_tokens_to_generate` to generate longer texts.
# * Inspect the quality of generated texts.

# %%
prompt = "Jide was thirsty so she went to Africa" #@param {type: "string"}
num_tokens_to_generate = 15 #@param {type: "number"}
generated_text, probs = generation.generate_text(
    prompt,
    num_tokens_to_generate,
    model=model,
    tokenizer=tokenizer,
    pad_token_id=tokenizer.pad_token_id,
    sampling_mode="random",
)

print("Generated text:", generated_text)
print("\n")

visualizations.plot_next_token(probs[0], prompt=prompt, tokenizer=tokenizer)
# Out:
# Generated text: Jide was thirsty so she went to Africa made from from cassava from from from from from from from from from from of
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ddbac99-3350-49c9-8444-2d8fff58b872" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ddbac99-3350-49c9-8444-2d8fff58b872")) {                    Plotly.newPlot(                        "3ddbac99-3350-49c9-8444-2d8fff58b872",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["'made'","'experiences'","'refers'","'a'","'of'","'in'","'enjoys'","'are'","'drink'","'from'","'was'","'popular'","'National'","'fermented'","'hot'","\"Africa's\"","'streets'","'Tanzania'","'by'","'or'","'cassava'","'but'","'closely'","'Moroccan'","'characterized'","'for'","'Nigeria'","'Mali,'","'an'","'East'"],"xaxis":"x","y":[0.31219044,0.052227836,0.04486251,0.039645374,0.0326164,0.015374057,0.014941022,0.012945283,0.011030905,0.006336274,0.0061472342,0.005218696,0.0042235176,0.0038856748,0.0037957157,0.0036468694,0.0034031617,0.003139915,0.003137206,0.0030078283,0.0029133419,0.0028721327,0.002766021,0.0025051113,0.002474375,0.002443685,0.0023906583,0.002280099,0.0022492902,0.002242508],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...

# %% [markdown]
# ## Summary
#
# This is the end of the **Train your own small language model** lab.
#
# In this lab, you trained your first SLM and engaged in the following steps.
#
# - **Tokenized the dataset:** You used the `SimpleWordTokenizer` from the previous lab to tokenize and convert the paragraphs in the dataset to token IDs.
#
# - **Padded the paragraphs:** You ensured all paragraphs had the same length by truncating some of them and padding others with a special `"<PAD>"` token. This is crucial for processing data in neural networks, such as transformer language models.
#
# - **Prepared the input and target data:** You created input-target pairs, where the target is the input sequence shifted by one token. This teaches the model to predict the next token based on the context of previous tokens.
#
# - **Shuffled and batched the data:** You shuffled the dataset to increase the diversity of the data within each batch and grouped the paragraphs into batches for training.
#
# - **Trained the SLM:** You defined and trained a small transformer model, observing how the training loss decreased during training.
#
# - **Prompted the trained model:** You experimented with prompting the model, observing its ability to predict the likely next word, generate coherent text, and adapt to changes in context.
#
# As you performed your evaluations, you may have noticed that some of the model predictions are not as good as the ones that you have seen with the Gemma model. This is expected since your model is a lot smaller than the Gemma model. It has been trained on *a lot* less text data. Nevertheless, your model should be able to produce grammatical sentences, even if they do not always make a lot of sense.
#
# In the next section of the course, you will explore model evaluation in a little more depth. You will then move on to think about the kinds of problems you are interested in using language models to address.

# %% [markdown]
# ## Solutions
#
# The following cells provide reference solutions to the coding activities above. If you really get stuck after trying to solve the activities yourself, you may want to consult these solutions.
#
# However, we recommend that you *only* look at the solutions after you have tried to solve the activities above *multiple times*. The best way to learn challenging concepts in computer science and artifical intelligence is to debug your code piece by piece until it works rather than copying existing solutions.
#
# If you feel stuck, you may want to first try to debug your code, for example, by adding additional print statements to see what your code is doing at every step. This will provide you with a much deeper understanding of the code and the materials. It will also make you practice how to solve challenging coding problems beyond this course.
#
# To view the solutions for an activity, click on the arrow to the left of the activity name. If you consult the solutions, do not copy and paste them into the cells above. Instead, look at them and then type them manually into the cell. This will help you understand where you went wrong.

# %% [markdown]
# ### Coding Activity 1

# %%
# Add this code in the cell for Activity 1 above.
longest_paragraph_length = len(max(encoded_tokens, key=len))
shortest_paragraph_length = len(min(encoded_tokens, key=len))
